# %% [markdown]
# ## Text Normalization
#
# Normalizing text is a critical component of text mining and a step we'll take on every single analysis. Eventually it'll get to the point that it's basically second nature. This notebook accompanies the lecture, where we mention six common types of text normalization:
#
# 1. Case folding
# 1. Removing punctuation
# 1. Handling numbers, dates, and times
# 1. Extracting special information
# 1. Removing stopwords
# 1. Correcting spelling
#
# We'll work through a few examples of most of these, although we'll save spelling correction for another day.

# %%
import nltk
from nltk.book import *
from collections import Counter
from nltk.corpus import stopwords

from string import punctuation
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ### 1. Case Folding
#
# We'll often discover that having a mixture of upper and lower case doesn't serve us very well. Case folding helps us handle this. Let's start by finding all the words that appear in the top 1000 most frequent words in the chat corpus with multiple capitalizations.

# %%
chat = text6
chat_count = Counter(chat)

# %%
chat_count
# Out:
# Counter({'SCENE': 24,
#          '1': 76,
#          ':': 1197,
#          '[': 319,
#          'wind': 3,
#          ']': 312,
#          'clop': 39,
#          'KING': 1,
#          'ARTHUR': 225,
#          'Whoa': 1,
#          'there': 25,
#          '!': 801,
#          'SOLDIER': 24,
#          '#': 127,
#          'Halt': 3,
#          'Who': 25,
#          'goes': 1,
#          '?': 207,
#          'It': 35,
#          'is': 106,
#          'I': 255,
#          ',': 731,
#          'Arthur': 36,
#          'son': 5,
#          'of': 158,
#          'Uther': 1,
#          'Pendragon': 1,
#          'from': 20,
#          'the': 299,
#          'castle': 18,
#          'Camelot': 26,
#          '.': 816,
#          'King': 27,
#          'Britons': 11,
#          'defeator': 1,
#          'Saxons': 1,
#          'sovereign': 1,
#          'all': 30,
#          'England': 2,
#          'Pull': 2,
#          'other': 5,
#          'one': 32,
#          'am': 22,
#          '...': 118,
#          'and': 135,
#          'this': 59,
#          'my': 38,
#          'trusty': 1,
#          'servant': 2,
#          'Patsy': 4,
#          'We': 60,
#          'have': 53,
#          'ridden': 2,
#          'length': 1,
#          'breadth': 1,
#          'land': 11,
#          'in': 86,
#          'search': 3,
#          'knights': 10,
#          'who': 21,
#          'will': 22,
#          'join': 7,
#          'me': 46,
#          'court': 3,
#          'at': 27,
#          'must': 23,
#          'speak': 2,
#          'with': 38,
#          'your': 75,
#          'lord': 3,
#          'master': 5,
#          'What': 65,
#          'Ridden': 1,
#          'on': 47,
#          'a': 188,
#          'horse': 1,
#          'Yes': 42,
#          'You': 61,
#          "'": 421,
#          're': 41,
#          'using': 1,
#          'coconuts': 3,
#          've': 21,
#          'got': 27,
#          'two': 8,
#          'empty': 2,
#          'halves': 1,
#          'coconut': 6,
#          'you': 204,
#          'bangin': 1,
#          'em': 3,
#          'together': 2,
#          'So': 14,
#          'since': 3,
#          'snows': 1,
#          'winter': 2,
#          'covered': 3,
#          'through': 9,
#          'kingdom': 3,
#          'Mercea': 2,
#          '--': 148,
#          'Where': 8,
#          'd': 12,
#          'get': 20,
#          'found': 8,
#          'them': 13,
#          'Found': 1,
#          'In': 11,
#          'The': 32,
#          's': 141,
#          'tropical': 1,
#          'do': 34,
#          'mean': 11,
#          'Well': 54,
#          'temperate': 1,
#          'zone': 1,
#          'swallow': 10,
#          'may': 9,
#          'fly': 1,
#          'south': 1,
#          'sun': 1,
#          'or': 9,
#          'house': 1,
#          'martin': 1,
#          'plover': 1,
#          'seek': 10,
#          'warmer': 1,
#          'climes': 1,
#          'yet': 3,
#          'these': 9,
#          'are': 52,
#          'not': 70,
#          'strangers': 1,
#          'to': 144,
#          'our': 11,
#          'Are': 6,
#          'suggesting': 1,
#          'migrate': 1,
#          'Not': 12,
#          'They': 8,
#          'could': 17,
#          'be': 43,
#          'carried': 5,
#          'A': 50,
#          'carrying': 1,
#          'grip': 1,
#          'it': 107,
#          'by': 14,
#          'husk': 1,
#          'question': 3,
#          'where': 6,
#          'he': 43,
#          'grips': 1,
#          'simple': 5,
#          'weight': 1,
#          'ratios': 1,
#          'five': 6,
#          'ounce': 1,
#          'bird': 1,
#          'carry': 3,
#          'pound': 7,
#          'doesn': 9,
#          't': 77,
#          'matter': 1,
#          'Will': 3,
#          'go': 22,
#          'tell': 24,
#          'that': 84,
#          'Court': 2,
#          'here': 34,
#          'Listen': 4,
#          'order': 2,
#          'maintain': 1,
#          'air': 2,
#          '-': 88,
#          'speed': 2,
#          'velocity': 2,
#          'needs': 1,
#          'beat': 4,
#          'its': 3,
#          'wings': 1,
#          'forty': 1,
#          'three': 8,
#          'times': 4,
#          'every': 3,
#          'second': 6,
#          'right': 21,
#          'Please': 10,
#          'Am': 1,
#          'm': 34,
#          'interested': 1,
#          '2': 42,
#          'an': 13,
#          'African': 4,
#          'Oh': 110,
#          'yeah': 7,
#          'maybe': 1,
#          'but': 32,
#          'European': 2,
#          'That': 22,
#          'point': 2,
#          'agree': 2,
#          'ask': 2,
#          'if': 24,
#          'wants': 1,
#          '?!': 12,
#          'But': 15,
#          'then': 15,
#          'course': 6,
#          'swallows': 5,
#          'non': 1,
#          'migratory': 1,
#          'they': 18,
#          'couldn': 1,
#          'bring': 1,
#          'back': 10,
#          'anyway': 4,
#          'Wait': 2,
#          'minute': 2,
#          'Supposing': 1,
#          'No': 76,
#          'line': 2,
#          'just': 25,
#          'use': 2,
#          'strand': 1,
#          'creeper': 1,
#          'held': 2,
#          'under': 2,
#          'dorsal': 1,
#          'guiding': 1,
#          'feathers': 1,
#          'why': 3,
#          'thud': 8,
#          'clang': 17,
#          'CART': 13,
#          'MASTER': 13,
#          'Bring': 14,
#          'out': 33,
#          'dead': 22,
#          'cough': 6,
#          '...]': 3,
#          '[...': 1,
#          'Ninepence': 2,
#          'rewr': 10,
#          '!]': 5,
#          'CUSTOMER': 13,
#          'Here': 4,
#          'DEAD': 8,
#          'PERSON': 8,
#          'Nothing': 2,
#          'ninepence': 1,
#          'Ere': 1,
#          'He': 46,
#          'says': 3,
#          'isn': 6,
#          'soon': 3,
#          'very': 17,
#          'ill': 1,
#          'getting': 3,
#          'better': 8,
#          'll': 19,
#          'stone': 2,
#          'moment': 1,
#          'can': 32,
#          'take': 11,
#          'him': 34,
#          'like': 15,
#          'against': 2,
#          'regulations': 1,
#          'don': 26,
#          'want': 13,
#          'cart': 1,
#          'such': 2,
#          'baby': 1,
#          'feel': 6,
#          'fine': 3,
#          'us': 32,
#          'favor': 2,
#          'hang': 1,
#          'around': 1,
#          'couple': 1,
#          'minutes': 2,
#          'won': 2,
#          'long': 3,
#          'Robinson': 1,
#          'lost': 3,
#          'nine': 1,
#          'today': 4,
#          'when': 12,
#          'next': 2,
#          'round': 3,
#          'Thursday': 2,
#          'think': 19,
#          'for': 33,
#          'walk': 1,
#          'fooling': 2,
#          'anyone': 3,
#          'know': 17,
#          'Look': 24,
#          'something': 3,
#          'singing': 31,
#          'happy': 3,
#          'whop': 4,
#          'Ah': 7,
#          'thanks': 1,
#          'much': 11,
#          'See': 2,
#          'Right': 27,
#          'All': 12,
#          'howl': 5,
#          'dunno': 1,
#          'Must': 1,
#          'king': 10,
#          'Why': 4,
#          'hasn': 1,
#          'shit': 2,
#          'over': 4,
#          '3': 12,
#          'music': 29,
#          'stops': 14,
#          'Old': 3,
#          'woman': 3,
#          'DENNIS': 21,
#          'Man': 3,
#          'Sorry': 7,
#          'knight': 5,
#          'live': 6,
#          'thirty': 2,
#          'seven': 2,
#          'what': 27,
#          'old': 7,
#          'call': 5,
#          "'.": 19,
#          'say': 14,
#          'Dennis': 4,
#          'didn': 11,
#          'were': 16,
#          'called': 2,
#          'bother': 2,
#          'find': 11,
#          'did': 10,
#          'sorry': 5,
#          'about': 13,
#          "',": 4,
#          'behind': 2,
#          'looked': 1,
#          'object': 1,
#          'automatically': 1,
#          'treat': 2,
#          'inferior': 1,
#          'eh': 7,
#          'nice': 8,
#          'And': 50,
#          'how': 6,
#          'By': 4,
#          'exploiting': 1,
#          'workers': 1,
#          'anging': 1,
#          'outdated': 1,
#          'imperialist': 1,
#          'dogma': 1,
#          'which': 10,
#          'perpetuates': 1,
#          'economic': 2,
#          'social': 1,
#          'differences': 1,
#          'society': 1,
#          'If': 9,
#          'ever': 3,
#          'going': 22,
#          'any': 6,
#          'progress': 1,
#          'WOMAN': 11,
#          'some': 8,
#          'lovely': 2,
#          'filth': 1,
#          'down': 7,
#          'How': 10,
#          'good': 11,
#          'lady': 2,
#          'we': 62,
#          'had': 13,
#          'thought': 4,
#          'autonomous': 1,
#          'collective': 1,
#          'yourself': 2,
#          'living': 3,
#          'dictatorship': 1,
#          'self': 1,
#          'perpetuating': 1,
#          'autocracy': 1,
#          'working': 1,
#          'classes': 1,
#          'bringing': 1,
#          'class': 1,
#          'into': 15,
#          'again': 10,
#          'only': 9,
#          'people': 6,
#          'would': 6,
#          'hear': 7,
#          'please': 8,
#          'haste': 1,
#          'lives': 2,
#          'Then': 8,
#          'told': 2,
#          'anarcho': 1,
#          'syndicalist': 1,
#          'commune': 1,
#          'turns': 1,
#          'act': 1,
#          'as': 15,
#          'sort': 3,
#          'executive': 3,
#          'officer': 2,
#          'week': 1,
#          'decision': 1,
#          'ratified': 1,
#          'special': 3,
#          'bi': 1,
#          'weekly': 1,
#          'meeting': 1,
#          'see': 17,
#          'majority': 2,
#          'case': 3,
#          'purely': 1,
#          'internal': 1,
#          'affairs': 1,
#          ',--': 2,
#          'Be': 3,
#          'quiet': 5,
#          'thirds': 1,
#          'more': 13,
#          'major': 1,
#          'Order': 1,
#          'does': 8,
#          'Heh': 10,
#          'vote': 2,
#          'kings': 2,
#          'become': 2,
#          'Lady': 1,
#          'Lake': 1,
#          'angels': 6,
#          'sing': 7,
#          'her': 40,
#          'arm': 4,
#          'clad': 1,
#          'purest': 1,
#          'shimmering': 1,
#          'samite': 1,
#          'aloft': 1,
#          'Excalibur': 2,
#          'bosom': 1,
#          'water': 4,
#          'signifying': 1,
#          'Divine': 1,
#          'Providence': 1,
#          'was': 24,
#          'strange': 2,
#          'women': 1,
#          'lying': 1,
#          'ponds': 1,
#          'distributing': 1,
#          'swords': 1,
#          'no': 55,
#          'basis': 1,
#          'system': 3,
#          'government': 1,
#          'Supreme': 1,
#          'power': 2,
#          'derives': 1,
#          'mandate': 1,
#          'masses': 1,
#          'farcical': 1,
#          'aquatic': 1,
#          'ceremony': 1,
#          'expect': 1,
#          'wield': 1,
#          'supreme': 1,
#          'cause': 2,
#          'watery': 1,
#          'tart': 1,
#          'threw': 1,
#          'sword': 3,
#          'Shut': 12,
#          'up': 36,
#          'went': 3,
#          'saying': 6,
#          'emperor': 1,
#          'because': 2,
#          'moistened': 1,
#          'bint': 1,
#          'lobbed': 1,
#          'scimitar': 1,
#          'put': 2,
#          'away': 38,
#          'now': 12,
#          'violence': 2,
#          'inherent': 2,
#          'Come': 26,
#          'Help': 1,
#          'help': 5,
#          'being': 3,
#          'repressed': 1,
#          'Bloody': 2,
#          'peasant': 1,
#          'give': 5,
#          'Did': 6,
#          'repressing': 1,
#          'saw': 17,
#          '4': 2,
#          'BLACK': 32,
#          'KNIGHT': 68,
#          'Aaagh': 4,
#          'GREEN': 5,
#          'Ooh': 5,
#          'stab': 1,
#          'Aagh': 2,
#          'Agh': 6,
#          '!,': 8,
#          'oh': 2,
#          'etc': 4,
#          'Aaaaaah': 1,
#          'Aaaaaaaaah': 1,
#          'woosh': 3,
#          'kills': 2,
#          'scrape': 1,
#          'Umm': 1,
#          'fight': 4,
#          'strength': 2,
#          'many': 4,
#          'men': 3,
#          'Sir': 52,
#          'Knight': 11,
#          'pause': 6,
#          'finest': 1,
#          'bravest': 1,
#          'proved': 1,
#          'worthy': 3,
#          'make': 12,
#          'sad': 2,
#          'None': 2,
#          'shall': 21,
#          'pass': 4,
#          'quarrel': 1,
#          'cross': 4,
#          'bridge': 2,
#          'die': 2,
#          'command': 2,
#          'stand': 3,
#          'aside': 2,
#          'move': 1,
#          'man': 12,
#          'Aaah': 3,
#          'hiyaah': 1,
#          'chops': 4,
#          'left': 2,
#          'off': 18,
#          'Now': 9,
#          'adversary': 1,
#          'Tis': 2,
#          'scratch': 2,
#          'Your': 1,
#          'worse': 1,
#          'liar': 1,
#          'pansy': 1,
#          'Huyah': 1,
#          'Hiyaah': 1,
#          'Aaaaaaaah': 1,
#          'Victory': 1,
#          'mine': 2,
#          'kneeling': 1,
#          'thank': 5,
#          'Thee': 2,
#          'Lord': 9,
#          'Thy': 1,
#          'mer': 1,
#          'Hah': 2,
#          'clunk': 5,
#          'Have': 3,
#          'kick': 4,
#          'Eh': 2,
#          'indeed': 1,
#          'brave': 17,
#          'enough': 4,
#          'stupid': 1,
#          'bastard': 1,
#          'arms': 1,
#          'Just': 10,
#          'flesh': 1,
#          'wound': 1,
#          'stop': 5,
#          'Chicken': 2,
#          'Chickennn': 1,
#          'leg': 3,
#          'bleed': 1,
#          'invincible': 1,
#          'looney': 1,
#          'Black': 4,
#          'always': 3,
#          'triumphs': 1,
#          'last': 7,
#          'draw': 1,
#          'Running': 1,
#          'yellow': 1,
#          'bastards': 1,
#          'coming': 2,
#          'bite': 1,
#          'legs': 1,
#          '5': 1,
#          'MONKS': 6,
#          'chanting': 6,
#          'Pie': 10,
#          'Iesu': 10,
#          'domine': 10,
#          'dona': 8,
#          'eis': 7,
#          'requiem': 8,
#          'bonk': 5,
#          'CROWD': 17,
#          'witch': 37,
#          'Burn': 32,
#          'VILLAGER': 47,
#          'May': 2,
#          'burn': 4,
#          'BEDEVERE': 61,
#          'she': 11,
#          'She': 7,
#          'looks': 2,
#          'Yeah': 8,
#          'forward': 2,
#          'WITCH': 4,
#          'Uh': 16,
#          'dressed': 2,
#          'Augh': 2,
#          'nose': 5,
#          'false': 1,
#          'hat': 1,
#          'Yeaaah': 1,
#          'Yeaah': 1,
#          'dress': 1,
#          'VILLAGERS': 2,
#          'bit': 10,
#          'has': 11,
#          'wart': 1,
#          'RANDOM': 8,
#          'makes': 1,
#          'turned': 3,
#          'newt': 2,
#          'Quiet': 4,
#          'There': 15,
#          'ways': 4,
#          'telling': 1,
#          'whether': 2,
#          'Tell': 3,
#          'witches': 4,
#          'apart': 3,
#          'More': 1,
#          'Shh': 15,
#          'Wood': 1,
#          'B': 4,
#          '--...': 1,
#          'made': 4,
#          'wood': 5,
#          'Good': 5,
#          'heh': 12,
#          'Build': 1,
#          'also': 2,
#          'bridges': 1,
#          'True': 1,
#          'Uhh': 2,
#          'Does': 1,
#          'sink': 1,
#          'floats': 3,
#          'Throw': 2,
#          'pond': 3,
#          'Bread': 1,
#          'Apples': 1,
#          'small': 2,
#          'rocks': 1,
#          'Cider': 1,
#          'gra': 1,
#          'gravy': 1,
#          'Cherries': 1,
#          'Mud': 1,
#          'Churches': 2,
#          'Lead': 2,
#          'duck': 5,
#          'Oooh': 7,
#          'Exactly': 1,
#          'logically': 1,
#          'weighs': 1,
#          'same': 4,
#          'therefore': 1,
#          'Use': 1,
#          'quack': 3,
#          'largest': 1,
#          'scales': 1,
#          'Ohh': 10,
#          'Ahh': 5,
#          'Remove': 1,
#          'supports': 1,
#          'creak': 2,
#          'fair': 3,
#          'cop': 1,
#          'so': 20,
#          'wise': 2,
#          'science': 1,
#          'My': 8,
#          'liege': 11,
#          'come': 18,
#          'Round': 8,
#          'Table': 8,
#          'honored': 1,
#          'name': 17,
#          'Bedevere': 6,
#          'dub': 1,
#          'NARRATOR': 17,
#          'first': 3,
#          'illustrious': 1,
#          'names': 2,
#          'follow': 1,
#          'Lancelot': 2,
#          'Brave': 5,
#          ';': 4,
#          'Gallahad': 1,
#          'Pure': 1,
#          'Robin': 19,
#          'quite': 7,
#          'nearly': 2,
#          'fought': 2,
#          'Dragon': 1,
#          'Angnor': 1,
#          'stood': 1,
#          'vicious': 2,
#          'Bristol': 1,
#          'personally': 1,
#          'wet': 1,
#          'himself': 1,
#          'Battle': 1,
#          'Badon': 1,
#          'Hill': 1,
#          'aptly': 1,
#          'named': 1,
#          'appearing': 1,
#          'film': 1,
#          'Together': 1,
#          'formed': 1,
#          'band': 1,
#          'whose': 2,
#          'deeds': 1,
#          'retold': 1,
#          'throughout': 1,
#          'centuries': 1,
#          'Knights': 18,
#          '6': 1,
#          'SIR': 4,
#          'earth': 1,
#          'banana': 1,
#          'shaped': 3,
#          'This': 8,
#          'new': 3,
#          'learning': 1,
#          'amazes': 1,
#          'Explain': 1,
#          'sheep': 1,
#          'bladders': 1,
#          'employed': 1,
#          'prevent': 1,
#          'earthquakes': 1,
#          'certainly': 1,
#          'sir': 16,
#          'LAUNCELOT': 76,
#          'trumpets': 4,
#          'GALAHAD': 69,
#          'PATSY': 1,
#          'model': 1,
#          'bid': 1,
#          'welcome': 1,
#          'home': 2,
#          'Let': 9,
#          'ride': 1,
#          'medieval': 2,
#          'hall': 3,
#          'KNIGHTS': 37,
#          'table': 1,
#          'dance': 1,
#          'e': 5,
#          'er': 2,
#          'able': 2,
#          'routines': 1,
#          'chorus': 1,
#          'scenes': 2,
#          'With': 2,
#          'footwork': 1,
#          'impeccable': 1,
#          'dine': 1,
#          'well': 8,
#          'eat': 2,
#          'ham': 1,
#          'jam': 1,
#          'spam': 1,
#          'lot': 7,
#          'dancing': 2,
#          'Our': 3,
#          'shows': 1,
#          'formidable': 1,
#          'given': 2,
#          'rhymes': 1,
#          'unsingable': 1,
#          'opera': 1,
#          'mad': 1,
#          'diaphragm': 1,
#          'dungeon': 1,
#          'PRISONER': 1,
#          'clap': 15,
#          'tap': 1,
#          'war': 1,
#          'tough': 1,
#          'Quite': 2,
#          'indefatigable': 1,
#          'Between': 1,
#          'quests': 1,
#          'sequin': 1,
#          'vests': 1,
#          'impersonate': 1,
#          'Clark': 1,
#          'Gable': 1,
#          'busy': 2,
#          'life': 4,
#          'MAN': 9,
#          'push': 2,
#          'pram': 1,
#          'outdoors': 1,
#          'let': 7,
#          'silly': 7,
#          'place': 5,
#          '7': 1,
#          'boom': 45,
#          'GOD': 6,
#          'grovel': 1,
#          'One': 5,
#          'thing': 4,
#          'groveling': 1,
#          'apologise': 1,
#          'Every': 1,
#          'time': 11,
#          'try': 2,
#          'talk': 3,
#          'someone': 4,
#          'forgive': 1,
#          'doing': 4,
#          'averting': 1,
#          'eyes': 3,
#          'O': 11,
#          'those': 4,
#          'miserable': 1,
#          'Psalms': 1,
#          'depressing': 1,
#          'knock': 1,
#          'task': 2,
#          'example': 1,
#          'dark': 2,
#          'idea': 4,
#          'Course': 2,
#          'Behold': 2,
#          'Holy': 24,
#          'Grail': 34,
#          'sacred': 7,
#          'grail': 5,
#          'purpose': 1,
#          'quest': 13,
#          'blessing': 2,
#          'God': 11,
#          'praised': 2,
#          '8': 1,
#          'horn': 1,
#          'Hallo': 2,
#          'FRENCH': 29,
#          'GUARD': 53,
#          'Allo': 2,
#          'eet': 1,
#          'Guy': 1,
#          'de': 2,
#          'Loimbard': 1,
#          'Go': 7,
#          'been': 7,
#          'charged': 1,
#          'food': 2,
#          'shelter': 1,
#          'night': 1,
#          'keen': 1,
#          'already': 4,
#          'sure': 12,
#          'yes': 11,
#          '(': 3,
#          '.)': 2,
#          'u': 2,
#          'um': 10,
#          'look': 7,
#          'Of': 3,
#          'English': 7,
#          'types': 2,
#          'French': 6,
#          'outrageous': 1,
#          'accent': 1,
#          'Mind': 1,
#          'own': 4,
#          'business': 1,
#          'show': 3,
#          'force': 2,
#          'frighten': 1,
#          'pig': 2,
#          'dogs': 1,
#          'boil': 1,
#          'bottom': 3,
#          'sons': 2,
#          'person': 4,
#          'blow': 2,
#          'k': 3,
#          'nnnnniggets': 1,
#          'Thpppppt': 1,
#          'Thppt': 2,
#          'wanna': 1,
#          'headed': 1,
#          'animal': 1,
#          'trough': 1,
#          'wiper': 1,
#          'fart': 1,
#          'general': 1,
#          'direction': 2,
#          'mother': 2,
#          'hamster': 1,
#          'father': 7,
#          'smelt': 1,
#          'elderberries': 1,
#          'Is': 5,
#          'else': 5,
#          'taunt': 2,
#          'sniff': 3,
#          'chance': 4,
#          'than': 4,
#          'reasonable': 1,
#          'Fetchez': 2,
#          'la': 2,
#          'vache': 2,
#          'OTHER': 1,
#          'Quoi': 2,
#          '!)': 1,
#          'mooo': 1,
#          'commands': 1,
#          'twong': 4,
#          'mooooooo': 1,
#          'Jesus': 3,
#          'Christ': 5,
#          'Charge': 4,
#          'mayhem': 2,
#          'Hey': 4,
#          'dad': 2,
#          'Run': 21,
#          'Thppppt': 1,
#          'GUARDS': 8,
#          'taunting': 5,
#          'Fiends': 1,
#          'tear': 1,
#          'plan': 1,
#          'later': 1,
#          'bang': 1,
#          'squeak': 29,
#          'rrrr': 3,
#          'drilllll': 1,
#          'sawwwww': 1,
#          'crash': 4,
#          'whispering': 2,
#          'C': 1,
#          'est': 1,
#          'un': 2,
#          'lapin': 2,
#          'bois': 1,
#          'Un': 1,
#          'cadeau': 2,
#          'present': 1,
#          'Oui': 1,
#          'oui': 1,
#          'Hurry': 5,
#          'On': 2,
#          'y': 3,
#          'va': 1,
#          'Bon': 1,
#          'magne': 1,
#          'Over': 2,
#          'clllank': 1,
#          'happens': 1,
#          'uh': 26,
#          'Launcelot': 25,
#          'Galahad': 11,
#          'wait': 1,
#          'until': 3,
#          'nightfall': 1,
#          'leap': 3,
#          ...})

# %%
chat_count.most_common(1000)
# Out:
# [(':', 1197),
#  ('.', 816),
#  ('!', 801),
#  (',', 731),
#  ("'", 421),
#  ('[', 319),
#  (']', 312),
#  ('the', 299),
#  ('I', 255),
#  ('ARTHUR', 225),
#  ('?', 207),
#  ('you', 204),
#  ('a', 188),
#  ('of', 158),
#  ('--', 148),
#  ('to', 144),
#  ('s', 141),
#  ('and', 135),
#  ('#', 127),
#  ('...', 118),
#  ('Oh', 110),
#  ('it', 107),
#  ('is', 106),
#  ('-', 88),
#  ('in', 86),
#  ('that', 84),
#  ('t', 77),
#  ('1', 76),
#  ('No', 76),
#  ('LAUNCELOT', 76),
#  ('your', 75),
#  ('not', 70),
#  ('GALAHAD', 69),
#  ('KNIGHT', 68),
#  ('What', 65),
#  ('FATHER', 63),
#  ('we', 62),
#  ('You', 61),
#  ('BEDEVERE', 61),
#  ('We', 60),
#  ('this', 59),
#  ('no', 55),
#  ('Well', 54),
#  ('HEAD', 54),
#  ('have', 53),
#  ('GUARD', 53),
#  ('are', 52),
#  ('Sir', 52),
#  ('A', 50),
#  ('And', 50),
#  ('on', 47),
#  ('VILLAGER', 47),
#  ('Ni', 47),
#  ('me', 46),
#  ('He', 46),
#  ('boom', 45),
#  ('be', 43),
#  ('he', 43),
#  ('Yes', 42),
#  ('2', 42),
#  ('ha', 42),
#  ('re', 41),
#  ('her', 40),
#  ('clop', 39),
#  ('ROBIN', 39),
#  ('my', 38),
#  ('with', 38),
#  ('away', 38),
#  ('witch', 37),
#  ('KNIGHTS', 37),
#  ('Arthur', 36),
#  ('up', 36),
#  ('It', 35),
#  ('do', 34),
#  ('here', 34),
#  ('m', 34),
#  ('him', 34),
#  ('Grail', 34),
#  ('out', 33),
#  ('for', 33),
#  ('one', 32),
#  ('The', 32),
#  ('but', 32),
#  ('can', 32),
#  ('us', 32),
#  ('BLACK', 32),
#  ('Burn', 32),
#  ('singing', 31),
#  ('all', 30),
#  ('TIM', 30),
#  ('mumble', 30),
#  ('music', 29),
#  ('FRENCH', 29),
#  ('squeak', 29),
#  ('King', 27),
#  ('at', 27),
#  ('got', 27),
#  ('Right', 27),
#  ('what', 27),
#  ('Camelot', 26),
#  ('don', 26),
#  ('Come', 26),
#  ('uh', 26),
#  ('Hello', 26),
#  ('HERBERT', 26),
#  ('there', 25),
#  ('Who', 25),
#  ('just', 25),
#  ('Launcelot', 25),
#  ('SCENE', 24),
#  ('SOLDIER', 24),
#  ('tell', 24),
#  ('if', 24),
#  ('Look', 24),
#  ('was', 24),
#  ('Holy', 24),
#  ('must', 23),
#  ('am', 22),
#  ('will', 22),
#  ('go', 22),
#  ('That', 22),
#  ('dead', 22),
#  ('going', 22),
#  ('his', 22),
#  ('who', 21),
#  ('ve', 21),
#  ('right', 21),
#  ('DENNIS', 21),
#  ('shall', 21),
#  ('Run', 21),
#  ('from', 20),
#  ('get', 20),
#  ('so', 20),
#  ('ll', 19),
#  ('think', 19),
#  ("'.", 19),
#  ('Robin', 19),
#  ('castle', 18),
#  ('they', 18),
#  ('off', 18),
#  ('come', 18),
#  ('Knights', 18),
#  ('could', 17),
#  ('clang', 17),
#  ('very', 17),
#  ('know', 17),
#  ('see', 17),
#  ('saw', 17),
#  ('brave', 17),
#  ('CROWD', 17),
#  ('name', 17),
#  ('NARRATOR', 17),
#  ('OF', 17),
#  ('Ha', 17),
#  ('GUESTS', 17),
#  ('were', 16),
#  ('Uh', 16),
#  ('sir', 16),
#  ('CARTOON', 16),
#  ('Stop', 16),
#  ('BRIDGEKEEPER', 16),
#  ('But', 15),
#  ('then', 15),
#  ('like', 15),
#  ('into', 15),
#  ('as', 15),
#  ('There', 15),
#  ('Shh', 15),
#  ('clap', 15),
#  ('DINGO', 15),
#  ('NI', 15),
#  ('So', 14),
#  ('by', 14),
#  ('Bring', 14),
#  ('stops', 14),
#  ('say', 14),
#  ('ZOOT', 14),
#  ('questions', 14),
#  ('them', 13),
#  ('an', 13),
#  ('CART', 13),
#  ('MASTER', 13),
#  ('CUSTOMER', 13),
#  ('want', 13),
#  ('about', 13),
#  ('had', 13),
#  ('more', 13),
#  ('quest', 13),
#  ('MINSTREL', 13),
#  ('hee', 13),
#  ('shrubbery', 13),
#  ('d', 12),
#  ('Not', 12),
#  ('?!', 12),
#  ('when', 12),
#  ('All', 12),
#  ('3', 12),
#  ('Shut', 12),
#  ('now', 12),
#  ('make', 12),
#  ('man', 12),
#  ('heh', 12),
#  ('sure', 12),
#  ('CHARACTER', 12),
#  ('GIRLS', 12),
#  ('CONCORDE', 12),
#  ('Three', 12),
#  ('MAYNARD', 12),
#  ('Britons', 11),
#  ('land', 11),
#  ('In', 11),
#  ('mean', 11),
#  ('our', 11),
#  ('take', 11),
#  ('much', 11),
#  ('didn', 11),
#  ('find', 11),
#  ('WOMAN', 11),
#  ('good', 11),
#  ('Knight', 11),
#  ('she', 11),
#  ('has', 11),
#  ('liege', 11),
#  ('time', 11),
#  ('O', 11),
#  ('God', 11),
#  ('yes', 11),
#  ('Galahad', 11),
#  ('leave', 11),
#  ('room', 11),
#  ('OFFICER', 11),
#  ('knights', 10),
#  ('swallow', 10),
#  ('seek', 10),
#  ('Please', 10),
#  ('back', 10),
#  ('rewr', 10),
#  ('king', 10),
#  ('did', 10),
#  ('which', 10),
#  ('How', 10),
#  ('again', 10),
#  ('Heh', 10),
#  ('Just', 10),
#  ('Pie', 10),
#  ('Iesu', 10),
#  ('domine', 10),
#  ('bit', 10),
#  ('Ohh', 10),
#  ('um', 10),
#  ('LEFT', 10),
#  ('Get', 10),
#  ('through', 9),
#  ('may', 9),
#  ('or', 9),
#  ('these', 9),
#  ('doesn', 9),
#  ('If', 9),
#  ('only', 9),
#  ('Now', 9),
#  ('Lord', 9),
#  ('Let', 9),
#  ('MAN', 9),
#  ('thou', 9),
#  ('Zoot', 9),
#  ('Thank', 9),
#  ('OLD', 9),
#  ('Hic', 9),
#  ('Hold', 9),
#  ('two', 8),
#  ('Where', 8),
#  ('found', 8),
#  ('They', 8),
#  ('three', 8),
#  ('thud', 8),
#  ('DEAD', 8),
#  ('PERSON', 8),
#  ('better', 8),
#  ('nice', 8),
#  ('some', 8),
#  ('please', 8),
#  ('Then', 8),
#  ('does', 8),
#  ('!,', 8),
#  ('dona', 8),
#  ('requiem', 8),
#  ('Yeah', 8),
#  ('RANDOM', 8),
#  ('My', 8),
#  ('Round', 8),
#  ('Table', 8),
#  ('This', 8),
#  ('well', 8),
#  ('GUARDS', 8),
#  ('rabbit', 8),
#  ('afraid', 8),
#  ('MIDDLE', 8),
#  ('cave', 8),
#  ('said', 8),
#  ('GUEST', 8),
#  ('join', 7),
#  ('pound', 7),
#  ('yeah', 7),
#  ('Ah', 7),
#  ('Sorry', 7),
#  ('old', 7),
#  ('eh', 7),
#  ('down', 7),
#  ('hear', 7),
#  ('sing', 7),
#  ('last', 7),
#  ('eis', 7),
#  ('She', 7),
#  ('Oooh', 7),
#  ('quite', 7),
#  ('lot', 7),
#  ('let', 7),
#  ('silly', 7),
#  ('sacred', 7),
#  ('Go', 7),
#  ('been', 7),
#  ('look', 7),
#  ('English', 7),
#  ('father', 7),
#  ('haw', 7),
#  ('To', 7),
#  ('cut', 7),
#  ('RIGHT', 7),
#  ('Castle', 7),
#  ('seen', 7),
#  ('spanking', 7),
#  ('peril', 7),
#  ('ni', 7),
#  ('dramatic', 7),
#  ('chord', 7),
#  ('lad', 7),
#  ('Concorde', 7),
#  ('CRONE', 7),
#  ('word', 7),
#  ('Aaaaugh', 7),
#  ('coconut', 6),
#  ('Are', 6),
#  ('where', 6),
#  ('five', 6),
#  ('second', 6),
#  ('course', 6),
#  ('cough', 6),
#  ('isn', 6),
#  ('feel', 6),
#  ('live', 6),
#  ('how', 6),
#  ('any', 6),
#  ('people', 6),
#  ('would', 6),
#  ('angels', 6),
#  ('saying', 6),
#  ('Did', 6),
#  ('Agh', 6),
#  ('pause', 6),
#  ('MONKS', 6),
#  ('chanting', 6),
#  ('Bedevere', 6),
#  ('GOD', 6),
#  ('French', 6),
#  ('Um', 6),
#  ('killed', 6),
#  ('really', 6),
#  ('nothing', 6),
#  ('bad', 6),
#  ('Back', 6),
#  ('scene', 6),
#  ('stay', 6),
#  ('Bridge', 6),
#  ('Death', 6),
#  ('Say', 6),
#  ('swamp', 6),
#  ('giggle', 6),
#  ('son', 5),
#  ('other', 5),
#  ('master', 5),
#  ('carried', 5),
#  ('simple', 5),
#  ('swallows', 5),
#  ('!]', 5),
#  ('howl', 5),
#  ('knight', 5),
#  ('call', 5),
#  ('sorry', 5),
#  ('quiet', 5),
#  ('help', 5),
#  ('give', 5),
#  ('GREEN', 5),
#  ('Ooh', 5),
#  ('thank', 5),
#  ('clunk', 5),
#  ('stop', 5),
#  ('bonk', 5),
#  ('nose', 5),
#  ('wood', 5),
#  ('Good', 5),
#  ('duck', 5),
#  ('Ahh', 5),
#  ('Brave', 5),
#  ('e', 5),
#  ('place', 5),
#  ('One', 5),
#  ('grail', 5),
#  ('Is', 5),
#  ('else', 5),
#  ('Christ', 5),
#  ('taunting', 5),
#  ('Hurry', 5),
#  ('i', 5),
#  ('built', 5),
#  ('HISTORIAN', 5),
#  ('forest', 5),
#  ('head', 5),
#  ('ALL', 5),
#  ('HEADS', 5),
#  ('j', 5),
#  ('kill', 5),
#  ('door', 5),
#  ('PIGLET', 5),
#  ('great', 5),
#  ('escape', 5),
#  ('easily', 5),
#  ('Ow', 5),
#  ('Father', 5),
#  ('upon', 5),
#  ('shrubberies', 5),
#  ('shalt', 5),
#  ('roar', 5),
#  ('INSPECTOR', 5),
#  ('Patsy', 4),
#  ('Listen', 4),
#  ('beat', 4),
#  ('times', 4),
#  ('African', 4),
#  ('anyway', 4),
#  ('Here', 4),
#  ('today', 4),
#  ('whop', 4),
#  ('Why', 4),
#  ('over', 4),
#  ('Dennis', 4),
#  ("',", 4),
#  ('By', 4),
#  ('thought', 4),
#  ('arm', 4),
#  ('water', 4),
#  ('Aaagh', 4),
#  ('etc', 4),
#  ('fight', 4),
#  ('many', 4),
#  ('pass', 4),
#  ('cross', 4),
#  ('chops', 4),
#  ('kick', 4),
#  ('enough', 4),
#  ('Black', 4),
#  ('burn', 4),
#  ('WITCH', 4),
#  ('Quiet', 4),
#  ('ways', 4),
#  ('witches', 4),
#  ('B', 4),
#  ('made', 4),
#  ('same', 4),
#  (';', 4),
#  ('SIR', 4),
#  ('trumpets', 4),
#  ('life', 4),
#  ('thing', 4),
#  ('someone', 4),
#  ('doing', 4),
#  ('those', 4),
#  ('idea', 4),
#  ('already', 4),
#  ('own', 4),
#  ('person', 4),
#  ('chance', 4),
#  ('than', 4),
#  ('twong', 4),
#  ('Charge', 4),
#  ('Hey', 4),
#  ('crash', 4),
#  ('surprise', 4),
#  ('S', 4),
#  ('each', 4),
#  ('north', 4),
#  ('shut', 4),
#  ('lies', 4),
#  ('twang', 4),
#  ('open', 4),
#  ('bed', 4),
#  ('big', 4),
#  ('cannot', 4),
#  ('wicked', 4),
#  ('naughty', 4),
#  ('Do', 4),
#  ('spank', 4),
#  ('Quick', 4),
#  ('single', 4),
#  ('handed', 4),
#  ('little', 4),
#  ('four', 4),
#  ('twenty', 4),
#  ('Hee', 4),
#  ('enchanter', 4),
#  ('whom', 4),
#  ('words', 4),
#  ('Prince', 4),
#  ('Until', 4),
#  ('keep', 4),
#  ('note', 4),
#  ('rescue', 4),
#  ('SENTRY', 4),
#  ('Aah', 4),
#  ('most', 4),
#  ('death', 4),
#  ('hand', 4),
#  ('path', 4),
#  ('Aaaugh', 4),
#  ('Tim', 4),
#  ('g', 4),
#  ('Hand', 4),
#  ('Grenade', 4),
#  ('Brother', 4),
#  ('BROTHER', 4),
#  ('Saint', 4),
#  ('thy', 4),
#  ('count', 4),
#  ('number', 4),
#  ('answer', 4),
#  ('along', 4),
#  ('wind', 3),
#  ('Halt', 3),
#  ('search', 3),
#  ('court', 3),
#  ('lord', 3),
#  ('coconuts', 3),
#  ('em', 3),
#  ('since', 3),
#  ('covered', 3),
#  ('kingdom', 3),
#  ('yet', 3),
#  ('question', 3),
#  ('carry', 3),
#  ('Will', 3),
#  ('its', 3),
#  ('every', 3),
#  ('why', 3),
#  ('...]', 3),
#  ('says', 3),
#  ('soon', 3),
#  ('getting', 3),
#  ('fine', 3),
#  ('long', 3),
#  ('lost', 3),
#  ('round', 3),
#  ('anyone', 3),
#  ('something', 3),
#  ('happy', 3),
#  ('Old', 3),
#  ('woman', 3),
#  ('Man', 3),
#  ('ever', 3),
#  ('living', 3),
#  ('sort', 3),
#  ('executive', 3),
#  ('special', 3),
#  ('case', 3),
#  ('Be', 3),
#  ('system', 3),
#  ('sword', 3),
#  ('went', 3),
#  ('being', 3),
#  ('woosh', 3),
#  ('men', 3),
#  ('worthy', 3),
#  ('stand', 3),
#  ('Aaah', 3),
#  ('Have', 3),
#  ('leg', 3),
#  ('always', 3),
#  ('turned', 3),
#  ('Tell', 3),
#  ('apart', 3),
#  ('floats', 3),
#  ('pond', 3),
#  ('quack', 3),
#  ('fair', 3),
#  ('first', 3),
#  ('shaped', 3),
#  ('new', 3),
#  ('hall', 3),
#  ('Our', 3),
#  ('talk', 3),
#  ('eyes', 3),
#  ('(', 3),
#  ('Of', 3),
#  ('show', 3),
#  ('bottom', 3),
#  ('k', 3),
#  ('sniff', 3),
#  ('Jesus', 3),
#  ('rrrr', 3),
#  ('y', 3),
#  ('until', 3),
#  ('leap', 3),
#  ('clank', 3),
#  ('..', 3),
#  ('eight', 3),
#  ('WIFE', 3),
#  ('Tale', 3),
#  ('favorite', 3),
#  ('nasty', 3),
#  ('least', 3),
#  ('burned', 3),
#  ('way', 3),
#  ('haven', 3),
#  ('n', 3),
#  ('biscuits', 3),
#  ('bravely', 3),
#  ('never', 3),
#  ('Wayy', 3),
#  ('Anthrax', 3),
#  ('need', 3),
#  ('between', 3),
#  ('doctors', 3),
#  ('wrong', 3),
#  ('At', 3),
#  ('longer', 3),
#  ('THE', 3),
#  ('sigh', 3),
#  ('oral', 3),
#  ('sex', 3),
#  ('foul', 3),
#  ('tackle', 3),
#  ('handle', 3),
#  ('fifty', 3),
#  ('too', 3),
#  ("'!", 3),
#  ('Hmm', 3),
#  ('Hm', 3),
#  ('SUN', 3),
#  ('Clear', 3),
#  ('sank', 3),
#  ('fell', 3),
#  ('listen', 3),
#  ('Don', 3),
#  ('Cut', 3),
#  ('Make', 3),
#  ('anything', 3),
#  ('seemed', 3),
#  ('scribble', 3),
#  (".'", 3),
#  ('died', 3),
#  ('Hiyya', 3),
#  ('knew', 3),
#  ('awfully', 3),
#  ('ready', 3),
#  ('splat', 3),
#  ('best', 3),
#  ('suddenly', 3),
#  ('Nu', 3),
#  ('ROGER', 3),
#  ("'?", 3),
#  ('ecky', 3),
#  ('another', 3),
#  ('running', 3),
#  ('looking', 3),
#  ('Yay', 3),
#  ('Winter', 3),
#  ('changed', 3),
#  ('Spring', 3),
#  ('Summer', 3),
#  ('Yup', 3),
#  ('Maynard', 3),
#  ('uuggggggh', 3),
#  ('Beast', 3),
#  ('attack', 3),
#  ('Hang', 3),
#  ('England', 2),
#  ('Pull', 2),
#  ('servant', 2),
#  ('ridden', 2),
#  ('speak', 2),
#  ('empty', 2),
#  ('together', 2),
#  ('winter', 2),
#  ('Mercea', 2),
#  ('Court', 2),
#  ('order', 2),
#  ('air', 2),
#  ('speed', 2),
#  ('velocity', 2),
#  ('European', 2),
#  ('point', 2),
#  ('agree', 2),
#  ('ask', 2),
#  ('Wait', 2),
#  ('minute', 2),
#  ('line', 2),
#  ('use', 2),
#  ('held', 2),
#  ('under', 2),
#  ('Ninepence', 2),
#  ('Nothing', 2),
#  ('stone', 2),
#  ('against', 2),
#  ('such', 2),
#  ('favor', 2),
#  ('minutes', 2),
#  ('won', 2),
#  ('next', 2),
#  ('Thursday', 2),
#  ('fooling', 2),
#  ('See', 2),
#  ('shit', 2),
#  ('thirty', 2),
#  ('seven', 2),
#  ('called', 2),
#  ('bother', 2),
#  ('behind', 2),
#  ('treat', 2),
#  ('economic', 2),
#  ('lovely', 2),
#  ('lady', 2),
#  ('yourself', 2),
#  ('lives', 2),
#  ('told', 2),
#  ('officer', 2),
#  ('majority', 2),
#  (',--', 2),
#  ('vote', 2),
#  ('kings', 2),
#  ('become', 2),
#  ('Excalibur', 2),
#  ('strange', 2),
#  ('power', 2),
#  ('cause', 2),
#  ('because', 2),
#  ('put', 2),
#  ('violence', 2),
#  ('inherent', 2),
#  ('Bloody', 2),
#  ('4', 2),
#  ('Aagh', 2),
#  ('oh', 2),
#  ('kills', 2),
#  ('strength', 2),
#  ('sad', 2),
#  ('None', 2),
#  ('bridge', 2),
#  ('die', 2),
#  ('command', 2),
#  ('aside', 2),
#  ('left', 2),
#  ('Tis', 2),
#  ('scratch', 2),
#  ('mine', 2),
#  ('Thee', 2),
#  ('Hah', 2),
#  ('Eh', 2),
#  ('Chicken', 2),
#  ('coming', 2),
#  ('May', 2),
#  ('looks', 2),
#  ('forward', 2),
#  ('dressed', 2),
#  ('Augh', 2),
#  ('VILLAGERS', 2),
#  ('newt', 2),
#  ('whether', 2),
#  ('also', 2),
#  ('Uhh', 2),
#  ('Throw', 2),
#  ('small', 2),
#  ('Churches', 2),
#  ('Lead', 2),
#  ('creak', 2),
#  ('wise', 2),
#  ('names', 2),
#  ('Lancelot', 2),
#  ('nearly', 2),
#  ('fought', 2),
#  ('vicious', 2),
#  ('whose', 2),
#  ('home', 2),
#  ('medieval', 2),
#  ('er', 2),
#  ('able', 2),
#  ('scenes', 2),
#  ('With', 2),
#  ('eat', 2),
#  ('dancing', 2),
#  ('given', 2),
#  ('Quite', 2),
#  ('busy', 2),
#  ('push', 2),
#  ('try', 2),
#  ('task', 2),
#  ('dark', 2),
#  ('Course', 2),
#  ('Behold', 2),
#  ('blessing', 2),
#  ('praised', 2),
#  ('Hallo', 2),
#  ('Allo', 2),
#  ('de', 2),
#  ('food', 2),
#  ('.)', 2),
#  ('u', 2),
#  ('types', 2),
#  ('force', 2),
#  ('pig', 2),
#  ('sons', 2),
#  ('blow', 2),
#  ('Thppt', 2),
#  ('direction', 2),
#  ('mother', 2),
#  ('taunt', 2),
#  ('Fetchez', 2),
#  ('la', 2),
#  ('vache', 2),
#  ('Quoi', 2),
#  ('mayhem', 2),
#  ('dad', 2),
#  ('whispering', 2),
#  ('un', 2),
#  ('lapin', 2),
#  ('cadeau', 2),
#  ('On', 2),
#  ('Over', 2),
#  ('taking', 2),
#  ('large', 2),
#  ('Haw', 2),
#  ('VOICE', 2),
#  ('seems', 2),
#  ('brought', 2),
#  ('should', 2),
#  ('separate', 2),
#  ('their', 2),
#  ('rode', 2),
#  ('minstrels', 2),
#  ('Bravely', 2),
#  ('scared', 2),
#  ('heart', 2),
#  ('work', 2),
#  ('freedom', 2),
#  ('art', 2),
#  ('passing', 2),
#  ('W', 2),
#  ('actually', 2),
#  ('Shall', 2),
#  ('Perhaps', 2),
#  ('teeth', 2),
#  ('tea', 2),
#  ('ran', 2),
#  ('When', 2),
#  ('danger', 2),
#  ('ooh', 2),
#  ('splash', 2),
#  ('ho', 2),
#  ('Open', 2),
#  ('thump', 2),
#  ('Welcome', 2),
#  ('keepers', 2),
#  ('rest', 2),
#  ('MIDGET', 2),
#  ('CRAPPER', 2),
#  ('guest', 2),
#  ('handsome', 2),
#  ('suffered', 2),
#  ('yours', 2),
#  ('young', 2),
#  ('exciting', 2),
#  ('used', 2),
#  ('Nay', 2),
#  ('lie', 2),
#  ('wounded', 2),
#  ('Doctor', 2),
#  ('once', 2),
#  ('setting', 2),
#  ('alight', 2),
#  ('beacon', 2),
#  ('problem', 2),
#  ('real', 2),
#  ('pay', 2),
#  ('penalty', 2),
#  ('ours', 2),
#  ('ENCHANTER', 2),
#  ('ARMY', 2),
#  ('after', 2),
#  ('saved', 2),
#  ('certain', 2),
#  ('flight', 2),
#  ('unladen', 2),
#  ('obviously', 2),
#  ('beyond', 2),
#  ('Gorge', 2),
#  ('Eternal', 2),
#  ('Peril', 2),
#  ('leads', 2),
#  ('Neee', 2),
#  ('wom', 2),
#  ('demand', 2),
#  ('return', 2),
#  ('Ay', 2),
#  ('Thsss', 2),
#  ('Ayy', 2),
#  ('day', 2),
#  ('curtains', 2),
#  ('daft', 2),
#  ('third', 2),
#  ('rather', 2),
#  ('while', 2),
#  ('girl', 2),
#  ('tracts', 2),
#  ('Herbert', 2),
#  ('bloody', 2),
#  ('huge', 2),
#  ('marry', 2),
#  ('Princess', 2),
#  ('even', 2),
#  ('enter', 2),
#  ('Leaving', 2),
#  ('N', 2),
#  ('meant', 2),
#  ('guard', 2),
#  ('clear', 2),
#  ('fold', 2),
#  ('Uuh', 2),
#  ('Tall', 2),
#  ('Tower', 2),
#  ('vain', 2),
#  ('pull', 2),
#  ('sweet', 2),
#  ('Idiom', 2),
#  ('PRINCESS', 2),
#  ('LUCKY', 2),
#  ('Morning', 2),
#  ('cost', 2),
#  ('explain', 2),
#  ('understand', 2),
#  ('bride', 2),
#  ('Very', 2),
#  ('Would', 2),
#  ('idiom', 2),
#  ('yelling', 2),
#  ('union', 2),
#  ('holy', 2),
#  ('daughter', 2),
#  ('For', 2),
#  ('fatal', 2),
#  ('Dramatically', 2),
#  ('Hoo', 2),
#  ('buy', 2),
#  ('Never', 2),
#  ('arrange', 2),
#  ('design', 2),
#  ('test', 2),
#  ('tree', 2),
#  ('herring', 2),
#  ('done', 2),
#  ('wouldn', 2),
#  ('far', 2),
#  ('sneaking', 2),
#  ('buggering', 2),
#  ('set', 2),
#  ('rejoicing', 2),
#  ('high', 2),
#  ('fire', 2),
#  ('Greetings', 2),
#  ('pweeng', 2),
#  ('Fine', 2),
#  ('suppose', 2),
#  ('Caerbannog', 2),
#  ('carved', 2),
#  ('rock', 2),
#  ('Follow', 2),
#  ('entrance', 2),
#  ('cruel', 2),
#  ('whinny', 2),
#  ('Keep', 2),
#  ('armor', 2),
#  ('Bors', 2),
#  ('BORS', 2),
#  ('warned', 2),
#  ('Antioch', 2),
#  ('Armaments', 2),
#  ('SECOND', 2),
#  ('grenade', 2),
#  ('tiny', 2),
#  ('Amen', 2),
#  ('Joseph', 2),
#  ('Arimathea', 2),
#  ('valiant', 2),
#  ('Aaauugh', 2)]

# %% [markdown]
# Now for a slightly easier one, how many times are "the" and "The" used in _Moby Dick_?

# %%
Counter(text1)['the']
# Out:
# 13721

# %%
Counter(text1)['The']
# Out:
# 612

# %% [markdown]
# I'll use a ***dictionary*** to hold all the words in the top 1000. The ***key*** will be the lowercase word and the ***value*** will be a ***list*** of every word that maps onto that lowercase word.

# %%
case_collisions = dict() # make a set to hold lowercase versions (key:value pair)

for word, count in chat_count.most_common(1000) : 
    # ie, taking the 1000 most common tokens in the data set selected above..
    # 'word' reflects the KEY and 'count' the VALUE for each ordered pair in chat_count
    lc_word = word.lower() # puts each key in lower-case and saves in variable 'lc_word'
    # assume word = ARTHUR, to lc_word = arthur
    
    if lc_word not in case_collisions : # starting with NOTHING in case_collissions...
        case_collisions[lc_word] = [word] # populate 1st pair:  'arthur' : ['ARTHUR']
    else : # assume next word is Arthur, so we already have 'arthur' as a key...
        case_collisions[lc_word].append(word) # appends the VALUE to ['ARTHUR','Arthur']

# %%
case_collisions
# Out:
# {':': [':'],
#  '.': ['.'],
#  '!': ['!'],
#  ',': [','],
#  "'": ["'"],
#  '[': ['['],
#  ']': [']'],
#  'the': ['the', 'The', 'THE'],
#  'i': ['I', 'i'],
#  'arthur': ['ARTHUR', 'Arthur'],
#  '?': ['?'],
#  'you': ['you', 'You'],
#  'a': ['a', 'A'],
#  'of': ['of', 'OF', 'Of'],
#  '--': ['--'],
#  'to': ['to', 'To'],
#  's': ['s', 'S'],
#  'and': ['and', 'And'],
#  '#': ['#'],
#  '...': ['...'],
#  'oh': ['Oh', 'oh'],
#  'it': ['it', 'It'],
#  'is': ['is', 'Is'],
#  '-': ['-'],
#  'in': ['in', 'In'],
#  'that': ['that', 'That'],
#  't': ['t'],
#  '1': ['1'],
#  'no': ['No', 'no'],
#  'launcelot': ['LAUNCELOT', 'Launcelot'],
#  'your': ['your'],
#  'not': ['not', 'Not'],
#  'galahad': ['GALAHAD', 'Galahad'],
#  'knight': ['KNIGHT', 'Knight', 'knight'],
#  'what': ['What', 'what'],
#  'father': ['FATHER', 'father', 'Father'],
#  'we': ['we', 'We'],
#  'bedevere': ['BEDEVERE', 'Bedevere'],
#  'this': ['this', 'This'],
#  'well': ['Well', 'well'],
#  'head': ['HEAD', 'head'],
#  'have': ['have', 'Have'],
#  'guard': ['GUARD', 'guard'],
#  'are': ['are', 'Are'],
#  'sir': ['Sir', 'sir', 'SIR'],
#  'on': ['on', 'On'],
#  'villager': ['VILLAGER'],
#  'ni': ['Ni', 'NI', 'ni'],
#  'me': ['me'],
#  'he': ['He', 'he'],
#  'boom': ['boom'],
#  'be': ['be', 'Be'],
#  'yes': ['Yes', 'yes'],
#  '2': ['2'],
#  'ha': ['ha', 'Ha'],
#  're': ['re'],
#  'her': ['her'],
#  'clop': ['clop'],
#  'robin': ['ROBIN', 'Robin'],
#  'my': ['my', 'My'],
#  'with': ['with', 'With'],
#  'away': ['away'],
#  'witch': ['witch', 'WITCH'],
#  'knights': ['KNIGHTS', 'Knights', 'knights'],
#  'up': ['up'],
#  'do': ['do', 'Do'],
#  'here': ['here', 'Here'],
#  'm': ['m'],
#  'him': ['him'],
#  'grail': ['Grail', 'grail'],
#  'out': ['out'],
#  'for': ['for', 'For'],
#  'one': ['one', 'One'],
#  'but': ['but', 'But'],
#  'can': ['can'],
#  'us': ['us'],
#  'black': ['BLACK', 'Black'],
#  'burn': ['Burn', 'burn'],
#  'singing': ['singing'],
#  'all': ['all', 'All', 'ALL'],
#  'tim': ['TIM', 'Tim'],
#  'mumble': ['mumble'],
#  'music': ['music'],
#  'french': ['FRENCH', 'French'],
#  'squeak': ['squeak'],
#  'king': ['King', 'king'],
#  'at': ['at', 'At'],
#  'got': ['got'],
#  'right': ['Right', 'right', 'RIGHT'],
#  'camelot': ['Camelot'],
#  'don': ['don', 'Don'],
#  'come': ['Come', 'come'],
#  'uh': ['uh', 'Uh'],
#  'hello': ['Hello'],
#  'herbert': ['HERBERT', 'Herbert'],
#  'there': ['there', 'There'],
#  'who': ['Who', 'who'],
#  'just': ['just', 'Just'],
#  'scene': ['SCENE', 'scene'],
#  'soldier': ['SOLDIER'],
#  'tell': ['tell', 'Tell'],
#  'if': ['if', 'If'],
#  'look': ['Look', 'look'],
#  'was': ['was'],
#  'holy': ['Holy', 'holy'],
#  'must': ['must'],
#  'am': ['am'],
#  'will': ['will', 'Will'],
#  'go': ['go', 'Go'],
#  'dead': ['dead', 'DEAD'],
#  'going': ['going'],
#  'his': ['his'],
#  've': ['ve'],
#  'dennis': ['DENNIS', 'Dennis'],
#  'shall': ['shall', 'Shall'],
#  'run': ['Run'],
#  'from': ['from'],
#  'get': ['get', 'Get'],
#  'so': ['so', 'So'],
#  'll': ['ll'],
#  'think': ['think'],
#  "'.": ["'."],
#  'castle': ['castle', 'Castle'],
#  'they': ['they', 'They'],
#  'off': ['off'],
#  'could': ['could'],
#  'clang': ['clang'],
#  'very': ['very', 'Very'],
#  'know': ['know'],
#  'see': ['see', 'See'],
#  'saw': ['saw'],
#  'brave': ['brave', 'Brave'],
#  'crowd': ['CROWD'],
#  'name': ['name'],
#  'narrator': ['NARRATOR'],
#  'guests': ['GUESTS'],
#  'were': ['were'],
#  'cartoon': ['CARTOON'],
#  'stop': ['Stop', 'stop'],
#  'bridgekeeper': ['BRIDGEKEEPER'],
#  'then': ['then', 'Then'],
#  'like': ['like'],
#  'into': ['into'],
#  'as': ['as'],
#  'shh': ['Shh'],
#  'clap': ['clap'],
#  'dingo': ['DINGO'],
#  'by': ['by', 'By'],
#  'bring': ['Bring'],
#  'stops': ['stops'],
#  'say': ['say', 'Say'],
#  'zoot': ['ZOOT', 'Zoot'],
#  'questions': ['questions'],
#  'them': ['them'],
#  'an': ['an'],
#  'cart': ['CART'],
#  'master': ['MASTER', 'master'],
#  'customer': ['CUSTOMER'],
#  'want': ['want'],
#  'about': ['about'],
#  'had': ['had'],
#  'more': ['more'],
#  'quest': ['quest'],
#  'minstrel': ['MINSTREL'],
#  'hee': ['hee', 'Hee'],
#  'shrubbery': ['shrubbery'],
#  'd': ['d'],
#  '?!': ['?!'],
#  'when': ['when', 'When'],
#  '3': ['3'],
#  'shut': ['Shut', 'shut'],
#  'now': ['now', 'Now'],
#  'make': ['make', 'Make'],
#  'man': ['man', 'MAN', 'Man'],
#  'heh': ['heh', 'Heh'],
#  'sure': ['sure'],
#  'character': ['CHARACTER'],
#  'girls': ['GIRLS'],
#  'concorde': ['CONCORDE', 'Concorde'],
#  'three': ['Three', 'three'],
#  'maynard': ['MAYNARD', 'Maynard'],
#  'britons': ['Britons'],
#  'land': ['land'],
#  'mean': ['mean'],
#  'our': ['our', 'Our'],
#  'take': ['take'],
#  'much': ['much'],
#  'didn': ['didn'],
#  'find': ['find'],
#  'woman': ['WOMAN', 'woman'],
#  'good': ['good', 'Good'],
#  'she': ['she', 'She'],
#  'has': ['has'],
#  'liege': ['liege'],
#  'time': ['time'],
#  'o': ['O'],
#  'god': ['God', 'GOD'],
#  'leave': ['leave'],
#  'room': ['room'],
#  'officer': ['OFFICER', 'officer'],
#  'swallow': ['swallow'],
#  'seek': ['seek'],
#  'please': ['Please', 'please'],
#  'back': ['back', 'Back'],
#  'rewr': ['rewr'],
#  'did': ['did', 'Did'],
#  'which': ['which'],
#  'how': ['How', 'how'],
#  'again': ['again'],
#  'pie': ['Pie'],
#  'iesu': ['Iesu'],
#  'domine': ['domine'],
#  'bit': ['bit'],
#  'ohh': ['Ohh'],
#  'um': ['um', 'Um'],
#  'left': ['LEFT', 'left'],
#  'through': ['through'],
#  'may': ['may', 'May'],
#  'or': ['or'],
#  'these': ['these'],
#  'doesn': ['doesn'],
#  'only': ['only'],
#  'lord': ['Lord', 'lord'],
#  'let': ['Let', 'let'],
#  'thou': ['thou'],
#  'thank': ['Thank', 'thank'],
#  'old': ['OLD', 'old', 'Old'],
#  'hic': ['Hic'],
#  'hold': ['Hold'],
#  'two': ['two'],
#  'where': ['Where', 'where'],
#  'found': ['found'],
#  'thud': ['thud'],
#  'person': ['PERSON', 'person'],
#  'better': ['better'],
#  'nice': ['nice'],
#  'some': ['some'],
#  'does': ['does'],
#  '!,': ['!,'],
#  'dona': ['dona'],
#  'requiem': ['requiem'],
#  'yeah': ['Yeah', 'yeah'],
#  'random': ['RANDOM'],
#  'round': ['Round', 'round'],
#  'table': ['Table'],
#  'guards': ['GUARDS'],
#  'rabbit': ['rabbit'],
#  'afraid': ['afraid'],
#  'middle': ['MIDDLE'],
#  'cave': ['cave'],
#  'said': ['said'],
#  'guest': ['GUEST', 'guest'],
#  'join': ['join'],
#  'pound': ['pound'],
#  'ah': ['Ah'],
#  'sorry': ['Sorry', 'sorry'],
#  'eh': ['eh', 'Eh'],
#  'down': ['down'],
#  'hear': ['hear'],
#  'sing': ['sing'],
#  'last': ['last'],
#  'eis': ['eis'],
#  'oooh': ['Oooh'],
#  'quite': ['quite', 'Quite'],
#  'lot': ['lot'],
#  'silly': ['silly'],
#  'sacred': ['sacred'],
#  'been': ['been'],
#  'english': ['English'],
#  'haw': ['haw', 'Haw'],
#  'cut': ['cut', 'Cut'],
#  'seen': ['seen'],
#  'spanking': ['spanking'],
#  'peril': ['peril', 'Peril'],
#  'dramatic': ['dramatic'],
#  'chord': ['chord'],
#  'lad': ['lad'],
#  'crone': ['CRONE'],
#  'word': ['word'],
#  'aaaaugh': ['Aaaaugh'],
#  'coconut': ['coconut'],
#  'five': ['five'],
#  'second': ['second', 'SECOND'],
#  'course': ['course', 'Course'],
#  'cough': ['cough'],
#  'isn': ['isn'],
#  'feel': ['feel'],
#  'live': ['live'],
#  'any': ['any'],
#  'people': ['people'],
#  'would': ['would', 'Would'],
#  'angels': ['angels'],
#  'saying': ['saying'],
#  'agh': ['Agh'],
#  'pause': ['pause'],
#  'monks': ['MONKS'],
#  'chanting': ['chanting'],
#  'killed': ['killed'],
#  'really': ['really'],
#  'nothing': ['nothing', 'Nothing'],
#  'bad': ['bad'],
#  'stay': ['stay'],
#  'bridge': ['Bridge', 'bridge'],
#  'death': ['Death', 'death'],
#  'swamp': ['swamp'],
#  'giggle': ['giggle'],
#  'son': ['son'],
#  'other': ['other'],
#  'carried': ['carried'],
#  'simple': ['simple'],
#  'swallows': ['swallows'],
#  '!]': ['!]'],
#  'howl': ['howl'],
#  'call': ['call'],
#  'quiet': ['quiet', 'Quiet'],
#  'help': ['help'],
#  'give': ['give'],
#  'green': ['GREEN'],
#  'ooh': ['Ooh', 'ooh'],
#  'clunk': ['clunk'],
#  'bonk': ['bonk'],
#  'nose': ['nose'],
#  'wood': ['wood'],
#  'duck': ['duck'],
#  'ahh': ['Ahh'],
#  'e': ['e'],
#  'place': ['place'],
#  'else': ['else'],
#  'christ': ['Christ'],
#  'taunting': ['taunting'],
#  'hurry': ['Hurry'],
#  'built': ['built'],
#  'historian': ['HISTORIAN'],
#  'forest': ['forest'],
#  'heads': ['HEADS'],
#  'j': ['j'],
#  'kill': ['kill'],
#  'door': ['door'],
#  'piglet': ['PIGLET'],
#  'great': ['great'],
#  'escape': ['escape'],
#  'easily': ['easily'],
#  'ow': ['Ow'],
#  'upon': ['upon'],
#  'shrubberies': ['shrubberies'],
#  'shalt': ['shalt'],
#  'roar': ['roar'],
#  'inspector': ['INSPECTOR'],
#  'patsy': ['Patsy'],
#  'listen': ['Listen', 'listen'],
#  'beat': ['beat'],
#  'times': ['times'],
#  'african': ['African'],
#  'anyway': ['anyway'],
#  'today': ['today'],
#  'whop': ['whop'],
#  'why': ['Why', 'why'],
#  'over': ['over', 'Over'],
#  "',": ["',"],
#  'thought': ['thought'],
#  'arm': ['arm'],
#  'water': ['water'],
#  'aaagh': ['Aaagh'],
#  'etc': ['etc'],
#  'fight': ['fight'],
#  'many': ['many'],
#  'pass': ['pass'],
#  'cross': ['cross'],
#  'chops': ['chops'],
#  'kick': ['kick'],
#  'enough': ['enough'],
#  'ways': ['ways'],
#  'witches': ['witches'],
#  'b': ['B'],
#  'made': ['made'],
#  'same': ['same'],
#  ';': [';'],
#  'trumpets': ['trumpets'],
#  'life': ['life'],
#  'thing': ['thing'],
#  'someone': ['someone'],
#  'doing': ['doing'],
#  'those': ['those'],
#  'idea': ['idea'],
#  'already': ['already'],
#  'own': ['own'],
#  'chance': ['chance'],
#  'than': ['than'],
#  'twong': ['twong'],
#  'charge': ['Charge'],
#  'hey': ['Hey'],
#  'crash': ['crash'],
#  'surprise': ['surprise'],
#  'each': ['each'],
#  'north': ['north'],
#  'lies': ['lies'],
#  'twang': ['twang'],
#  'open': ['open', 'Open'],
#  'bed': ['bed'],
#  'big': ['big'],
#  'cannot': ['cannot'],
#  'wicked': ['wicked'],
#  'naughty': ['naughty'],
#  'spank': ['spank'],
#  'quick': ['Quick'],
#  'single': ['single'],
#  'handed': ['handed'],
#  'little': ['little'],
#  'four': ['four'],
#  'twenty': ['twenty'],
#  'enchanter': ['enchanter', 'ENCHANTER'],
#  'whom': ['whom'],
#  'words': ['words'],
#  'prince': ['Prince'],
#  'until': ['Until', 'until'],
#  'keep': ['keep', 'Keep'],
#  'note': ['note'],
#  'rescue': ['rescue'],
#  'sentry': ['SENTRY'],
#  'aah': ['Aah'],
#  'most': ['most'],
#  'hand': ['hand', 'Hand'],
#  'path': ['path'],
#  'aaaugh': ['Aaaugh'],
#  'g': ['g'],
#  'grenade': ['Grenade', 'grenade'],
#  'brother': ['Brother', 'BROTHER'],
#  'saint': ['Saint'],
#  'thy': ['thy'],
#  'count': ['count'],
#  'number': ['number'],
#  'answer': ['answer'],
#  'along': ['along'],
#  'wind': ['wind'],
#  'halt': ['Halt'],
#  'search': ['search'],
#  'court': ['court', 'Court'],
#  'coconuts': ['coconuts'],
#  'em': ['em'],
#  'since': ['since'],
#  'covered': ['covered'],
#  'kingdom': ['kingdom'],
#  'yet': ['yet'],
#  'question': ['question'],
#  'carry': ['carry'],
#  'its': ['its'],
#  'every': ['every'],
#  '...]': ['...]'],
#  'says': ['says'],
#  'soon': ['soon'],
#  'getting': ['getting'],
#  'fine': ['fine', 'Fine'],
#  'long': ['long'],
#  'lost': ['lost'],
#  'anyone': ['anyone'],
#  'something': ['something'],
#  'happy': ['happy'],
#  'ever': ['ever'],
#  'living': ['living'],
#  'sort': ['sort'],
#  'executive': ['executive'],
#  'special': ['special'],
#  'case': ['case'],
#  'system': ['system'],
#  'sword': ['sword'],
#  'went': ['went'],
#  'being': ['being'],
#  'woosh': ['woosh'],
#  'men': ['men'],
#  'worthy': ['worthy'],
#  'stand': ['stand'],
#  'aaah': ['Aaah'],
#  'leg': ['leg'],
#  'always': ['always'],
#  'turned': ['turned'],
#  'apart': ['apart'],
#  'floats': ['floats'],
#  'pond': ['pond'],
#  'quack': ['quack'],
#  'fair': ['fair'],
#  'first': ['first'],
#  'shaped': ['shaped'],
#  'new': ['new'],
#  'hall': ['hall'],
#  'talk': ['talk'],
#  'eyes': ['eyes'],
#  '(': ['('],
#  'show': ['show'],
#  'bottom': ['bottom'],
#  'k': ['k'],
#  'sniff': ['sniff'],
#  'jesus': ['Jesus'],
#  'rrrr': ['rrrr'],
#  'y': ['y'],
#  'leap': ['leap'],
#  'clank': ['clank'],
#  '..': ['..'],
#  'eight': ['eight'],
#  'wife': ['WIFE'],
#  'tale': ['Tale'],
#  'favorite': ['favorite'],
#  'nasty': ['nasty'],
#  'least': ['least'],
#  'burned': ['burned'],
#  'way': ['way'],
#  'haven': ['haven'],
#  'n': ['n', 'N'],
#  'biscuits': ['biscuits'],
#  'bravely': ['bravely', 'Bravely'],
#  'never': ['never', 'Never'],
#  'wayy': ['Wayy'],
#  'anthrax': ['Anthrax'],
#  'need': ['need'],
#  'between': ['between'],
#  'doctors': ['doctors'],
#  'wrong': ['wrong'],
#  'longer': ['longer'],
#  'sigh': ['sigh'],
#  'oral': ['oral'],
#  'sex': ['sex'],
#  'foul': ['foul'],
#  'tackle': ['tackle'],
#  'handle': ['handle'],
#  'fifty': ['fifty'],
#  'too': ['too'],
#  "'!": ["'!"],
#  'hmm': ['Hmm'],
#  'hm': ['Hm'],
#  'sun': ['SUN'],
#  'clear': ['Clear', 'clear'],
#  'sank': ['sank'],
#  'fell': ['fell'],
#  'anything': ['anything'],
#  'seemed': ['seemed'],
#  'scribble': ['scribble'],
#  ".'": [".'"],
#  'died': ['died'],
#  'hiyya': ['Hiyya'],
#  'knew': ['knew'],
#  'awfully': ['awfully'],
#  'ready': ['ready'],
#  'splat': ['splat'],
#  'best': ['best'],
#  'suddenly': ['suddenly'],
#  'nu': ['Nu'],
#  'roger': ['ROGER'],
#  "'?": ["'?"],
#  'ecky': ['ecky'],
#  'another': ['another'],
#  'running': ['running'],
#  'looking': ['looking'],
#  'yay': ['Yay'],
#  'winter': ['Winter', 'winter'],
#  'changed': ['changed'],
#  'spring': ['Spring'],
#  'summer': ['Summer'],
#  'yup': ['Yup'],
#  'uuggggggh': ['uuggggggh'],
#  'beast': ['Beast'],
#  'attack': ['attack'],
#  'hang': ['Hang'],
#  'england': ['England'],
#  'pull': ['Pull', 'pull'],
#  'servant': ['servant'],
#  'ridden': ['ridden'],
#  'speak': ['speak'],
#  'empty': ['empty'],
#  'together': ['together'],
#  'mercea': ['Mercea'],
#  'order': ['order'],
#  'air': ['air'],
#  'speed': ['speed'],
#  'velocity': ['velocity'],
#  'european': ['European'],
#  'point': ['point'],
#  'agree': ['agree'],
#  'ask': ['ask'],
#  'wait': ['Wait'],
#  'minute': ['minute'],
#  'line': ['line'],
#  'use': ['use'],
#  'held': ['held'],
#  'under': ['under'],
#  'ninepence': ['Ninepence'],
#  'stone': ['stone'],
#  'against': ['against'],
#  'such': ['such'],
#  'favor': ['favor'],
#  'minutes': ['minutes'],
#  'won': ['won'],
#  'next': ['next'],
#  'thursday': ['Thursday'],
#  'fooling': ['fooling'],
#  'shit': ['shit'],
#  'thirty': ['thirty'],
#  'seven': ['seven'],
#  'called': ['called'],
#  'bother': ['bother'],
#  'behind': ['behind'],
#  'treat': ['treat'],
#  'economic': ['economic'],
#  'lovely': ['lovely'],
#  'lady': ['lady'],
#  'yourself': ['yourself'],
#  'lives': ['lives'],
#  'told': ['told'],
#  'majority': ['majority'],
#  ',--': [',--'],
#  'vote': ['vote'],
#  'kings': ['kings'],
#  'become': ['become'],
#  'excalibur': ['Excalibur'],
#  'strange': ['strange'],
#  'power': ['power'],
#  'cause': ['cause'],
#  'because': ['because'],
#  'put': ['put'],
#  'violence': ['violence'],
#  'inherent': ['inherent'],
#  'bloody': ['Bloody', 'bloody'],
#  '4': ['4'],
#  'aagh': ['Aagh'],
#  'kills': ['kills'],
#  'strength': ['strength'],
#  'sad': ['sad'],
#  'none': ['None'],
#  'die': ['die'],
#  'command': ['command'],
#  'aside': ['aside'],
#  'tis': ['Tis'],
#  'scratch': ['scratch'],
#  'mine': ['mine'],
#  'thee': ['Thee'],
#  'hah': ['Hah'],
#  'chicken': ['Chicken'],
#  'coming': ['coming'],
#  'looks': ['looks'],
#  'forward': ['forward'],
#  'dressed': ['dressed'],
#  'augh': ['Augh'],
#  'villagers': ['VILLAGERS'],
#  'newt': ['newt'],
#  'whether': ['whether'],
#  'also': ['also'],
#  'uhh': ['Uhh'],
#  'throw': ['Throw'],
#  'small': ['small'],
#  'churches': ['Churches'],
#  'lead': ['Lead'],
#  'creak': ['creak'],
#  'wise': ['wise'],
#  'names': ['names'],
#  'lancelot': ['Lancelot'],
#  'nearly': ['nearly'],
#  'fought': ['fought'],
#  'vicious': ['vicious'],
#  'whose': ['whose'],
#  'home': ['home'],
#  'medieval': ['medieval'],
#  'er': ['er'],
#  'able': ['able'],
#  'scenes': ['scenes'],
#  'eat': ['eat'],
#  'dancing': ['dancing'],
#  'given': ['given'],
#  'busy': ['busy'],
#  'push': ['push'],
#  'try': ['try'],
#  'task': ['task'],
#  'dark': ['dark'],
#  'behold': ['Behold'],
#  'blessing': ['blessing'],
#  'praised': ['praised'],
#  'hallo': ['Hallo'],
#  'allo': ['Allo'],
#  'de': ['de'],
#  'food': ['food'],
#  '.)': ['.)'],
#  'u': ['u'],
#  'types': ['types'],
#  'force': ['force'],
#  'pig': ['pig'],
#  'sons': ['sons'],
#  'blow': ['blow'],
#  'thppt': ['Thppt'],
#  'direction': ['direction'],
#  'mother': ['mother'],
#  'taunt': ['taunt'],
#  'fetchez': ['Fetchez'],
#  'la': ['la'],
#  'vache': ['vache'],
#  'quoi': ['Quoi'],
#  'mayhem': ['mayhem'],
#  'dad': ['dad'],
#  'whispering': ['whispering'],
#  'un': ['un'],
#  'lapin': ['lapin'],
#  'cadeau': ['cadeau'],
#  'taking': ['taking'],
#  'large': ['large'],
#  'voice': ['VOICE'],
#  'seems': ['seems'],
#  'brought': ['brought'],
#  'should': ['should'],
#  'separate': ['separate'],
#  'their': ['their'],
#  'rode': ['rode'],
#  'minstrels': ['minstrels'],
#  'scared': ['scared'],
#  'heart': ['heart'],
#  'work': ['work'],
#  'freedom': ['freedom'],
#  'art': ['art'],
#  'passing': ['passing'],
#  'w': ['W'],
#  'actually': ['actually'],
#  'perhaps': ['Perhaps'],
#  'teeth': ['teeth'],
#  'tea': ['tea'],
#  'ran': ['ran'],
#  'danger': ['danger'],
#  'splash': ['splash'],
#  'ho': ['ho'],
#  'thump': ['thump'],
#  'welcome': ['Welcome'],
#  'keepers': ['keepers'],
#  'rest': ['rest'],
#  'midget': ['MIDGET'],
#  'crapper': ['CRAPPER'],
#  'handsome': ['handsome'],
#  'suffered': ['suffered'],
#  'yours': ['yours'],
#  'young': ['young'],
#  'exciting': ['exciting'],
#  'used': ['used'],
#  'nay': ['Nay'],
#  'lie': ['lie'],
#  'wounded': ['wounded'],
#  'doctor': ['Doctor'],
#  'once': ['once'],
#  'setting': ['setting'],
#  'alight': ['alight'],
#  'beacon': ['beacon'],
#  'problem': ['problem'],
#  'real': ['real'],
#  'pay': ['pay'],
#  'penalty': ['penalty'],
#  'ours': ['ours'],
#  'army': ['ARMY'],
#  'after': ['after'],
#  'saved': ['saved'],
#  'certain': ['certain'],
#  'flight': ['flight'],
#  'unladen': ['unladen'],
#  'obviously': ['obviously'],
#  'beyond': ['beyond'],
#  'gorge': ['Gorge'],
#  'eternal': ['Eternal'],
#  'leads': ['leads'],
#  'neee': ['Neee'],
#  'wom': ['wom'],
#  'demand': ['demand'],
#  'return': ['return'],
#  'ay': ['Ay'],
#  'thsss': ['Thsss'],
#  'ayy': ['Ayy'],
#  'day': ['day'],
#  'curtains': ['curtains'],
#  'daft': ['daft'],
#  'third': ['third'],
#  'rather': ['rather'],
#  'while': ['while'],
#  'girl': ['girl'],
#  'tracts': ['tracts'],
#  'huge': ['huge'],
#  'marry': ['marry'],
#  'princess': ['Princess', 'PRINCESS'],
#  'even': ['even'],
#  'enter': ['enter'],
#  'leaving': ['Leaving'],
#  'meant': ['meant'],
#  'fold': ['fold'],
#  'uuh': ['Uuh'],
#  'tall': ['Tall'],
#  'tower': ['Tower'],
#  'vain': ['vain'],
#  'sweet': ['sweet'],
#  'idiom': ['Idiom', 'idiom'],
#  'lucky': ['LUCKY'],
#  'morning': ['Morning'],
#  'cost': ['cost'],
#  'explain': ['explain'],
#  'understand': ['understand'],
#  'bride': ['bride'],
#  'yelling': ['yelling'],
#  'union': ['union'],
#  'daughter': ['daughter'],
#  'fatal': ['fatal'],
#  'dramatically': ['Dramatically'],
#  'hoo': ['Hoo'],
#  'buy': ['buy'],
#  'arrange': ['arrange'],
#  'design': ['design'],
#  'test': ['test'],
#  'tree': ['tree'],
#  'herring': ['herring'],
#  'done': ['done'],
#  'wouldn': ['wouldn'],
#  'far': ['far'],
#  'sneaking': ['sneaking'],
#  'buggering': ['buggering'],
#  'set': ['set'],
#  'rejoicing': ['rejoicing'],
#  'high': ['high'],
#  'fire': ['fire'],
#  'greetings': ['Greetings'],
#  'pweeng': ['pweeng'],
#  'suppose': ['suppose'],
#  'caerbannog': ['Caerbannog'],
#  'carved': ['carved'],
#  'rock': ['rock'],
#  'follow': ['Follow'],
#  'entrance': ['entrance'],
#  'cruel': ['cruel'],
#  'whinny': ['whinny'],
#  'armor': ['armor'],
#  'bors': ['Bors', 'BORS'],
#  'warned': ['warned'],
#  'antioch': ['Antioch'],
#  'armaments': ['Armaments'],
#  'tiny': ['tiny'],
#  'amen': ['Amen'],
#  'joseph': ['Joseph'],
#  'arimathea': ['Arimathea'],
#  'valiant': ['valiant'],
#  'aaauugh': ['Aaauugh']}

# %% [markdown]
# ***F-strings*** provide a way to embed expressions inside string literals, using a minimal syntax. It should be noted that an f-string is really an expression evaluated at run time, not a constant value. In Python source code, an f-string is a literal string, prefixed with f , which contains expressions inside braces.
# - ACTION(f'some_opening_text {"separator".join(VALUE_name)} map onto {KEY_name}')
# - ex: print(f'The words {",".join(wlist)} map onto {word}')

# %%
for word, wlist in case_collisions.items() :
    # 'word' reflects the KEY and 'wlist' the VALUE (a LIST) 
    # for each ordered pair in case_collisions pairs 
    if len(wlist) > 1 : # ie, if the VALUE(list) contents for any record > 1 element
        print(f'The words {",".join(wlist)} map onto {word}')
        #print(f'The words {"?".join(wlist)} map onto {word}')
        #print('The words {"?".join(wlist)} map onto {word}')
        # using the new-ish f strings
# Out:
# The words the,The,THE map onto the
# The words I,i map onto i
# The words ARTHUR,Arthur map onto arthur
# The words you,You map onto you
# The words a,A map onto a
# The words of,OF,Of map onto of
# The words to,To map onto to
# The words s,S map onto s
# The words and,And map onto and
# The words Oh,oh map onto oh
# The words it,It map onto it
# The words is,Is map onto is
# The words in,In map onto in
# The words that,That map onto that
# The words No,no map onto no
# The words LAUNCELOT,Launcelot map onto launcelot
# The words not,Not map onto not
# The words GALAHAD,Galahad map onto galahad
# The words KNIGHT,Knight,knight map onto knight
# The words What,what map onto what
# The words FATHER,father,Father map onto father
# The words we,We map onto we
# The words BEDEVERE,Bedevere map onto bedevere
# The words this,This map onto this
# The words Well,well map onto well
# The words HEAD,head map onto head
# The words have,Have map onto have
# The words GUARD,guard map onto guard
# The words are,Are map onto are
# The words Sir,sir,SIR map onto sir
# The words on,On map onto on
# The words Ni,NI,ni map onto ni
# The words He,he map onto he
# The words be,Be map onto be
# The words Yes,yes map onto yes
# The words ha,Ha map onto ha
# The words ROBIN,Robin map onto robin
# The words my,My map onto my
# The words with,With map onto with
# The words witch,WITCH map onto witch
# The words KNIGHTS,Knights,knights map onto knights
# The words do,Do map onto do
# The words here,Here map onto here
# The words Grail,grail map onto grail
# The words for,For map onto for
# The words one,One map onto one
# The words but,But map onto but
# The words BLACK,Black map onto black
# The words Burn,burn map onto burn
# The words all,All,ALL map onto all
# The words TIM,Tim map onto tim
# The words FRENCH,French map onto french
# The words King,king map onto king
# The words at,At map onto at
# The words Right,right,RIGHT map onto right
# The words don,Don map onto don
# The words Come,come map onto come
# The words uh,Uh map onto uh
# The words HERBERT,Herbert map onto herbert
# The words there,There map onto there
# The words Who,who map onto who
# The words just,Just map onto just
# The words SCENE,scene map onto scene
# The words tell,Tell map onto tell
# The words if,If map onto if
# The words Look,look map onto look
# The words Holy,holy map onto holy
# The words will,Will map onto will
# The words go,Go map onto go
# The words dead,DEAD map onto dead
# The words DENNIS,Dennis map onto dennis
# The words shall,Shall map onto shall
# The words get,Get map onto get
# The words so,So map onto so
# The words castle,Castle map onto castle
# The words they,They map onto they
# The words very,Very map onto very
# The words see,See map onto see
# The words brave,Brave map onto brave
# The words Stop,stop map onto stop
# The words then,Then map onto then
# The words by,By map onto by
# The words say,Say map onto say
# The words ZOOT,Zoot map onto zoot
# The words MASTER,master map onto master
# The words hee,Hee map onto hee
# The words when,When map onto when
# The words Shut,shut map onto shut
# The words now,Now map onto now
# The words make,Make map onto make
# The words man,MAN,Man map onto man
# The words heh,Heh map onto heh
# The words CONCORDE,Concorde map onto concorde
# The words Three,three map onto three
# The words MAYNARD,Maynard map onto maynard
# The words our,Our map onto our
# The words WOMAN,woman map onto woman
# The words good,Good map onto good
# The words she,She map onto she
# The words God,GOD map onto god
# The words OFFICER,officer map onto officer
# The words Please,please map onto please
# The words back,Back map onto back
# The words did,Did map onto did
# The words How,how map onto how
# The words um,Um map onto um
# The words LEFT,left map onto left
# The words may,May map onto may
# The words Lord,lord map onto lord
# The words Let,let map onto let
# The words Thank,thank map onto thank
# The words OLD,old,Old map onto old
# The words Where,where map onto where
# The words PERSON,person map onto person
# The words Yeah,yeah map onto yeah
# The words Round,round map onto round
# The words GUEST,guest map onto guest
# The words Sorry,sorry map onto sorry
# The words eh,Eh map onto eh
# The words quite,Quite map onto quite
# The words haw,Haw map onto haw
# The words cut,Cut map onto cut
# The words peril,Peril map onto peril
# The words second,SECOND map onto second
# The words course,Course map onto course
# The words would,Would map onto would
# The words nothing,Nothing map onto nothing
# The words Bridge,bridge map onto bridge
# The words Death,death map onto death
# The words quiet,Quiet map onto quiet
# The words Ooh,ooh map onto ooh
# The words Listen,listen map onto listen
# The words Why,why map onto why
# The words over,Over map onto over
# The words open,Open map onto open
# The words enchanter,ENCHANTER map onto enchanter
# The words Until,until map onto until
# The words keep,Keep map onto keep
# The words hand,Hand map onto hand
# The words Grenade,grenade map onto grenade
# The words Brother,BROTHER map onto brother
# The words court,Court map onto court
# The words fine,Fine map onto fine
# The words n,N map onto n
# The words bravely,Bravely map onto bravely
# The words never,Never map onto never
# The words Clear,clear map onto clear
# The words Winter,winter map onto winter
# The words Pull,pull map onto pull
# The words Bloody,bloody map onto bloody
# The words Princess,PRINCESS map onto princess
# The words Idiom,idiom map onto idiom
# The words Bors,BORS map onto bors

# %%
# tweak the sentence ordering (swapping positions of KEY and VALUE references)
for word, wlist in case_collisions.items() :
    # 'word' reflects the KEY and 'wlist' the VALUE (a LIST) 
    # for each ordered pair in case_collisions pairs 
    if len(wlist) > 1 : # ie, if the VALUE(list) contents for any record > 1 element
        print(f'The word {word} maps with {"=>".join(wlist)}')
# Out:
# The word the maps with the=>The=>THE
# The word i maps with I=>i
# The word arthur maps with ARTHUR=>Arthur
# The word you maps with you=>You
# The word a maps with a=>A
# The word of maps with of=>OF=>Of
# The word to maps with to=>To
# The word s maps with s=>S
# The word and maps with and=>And
# The word oh maps with Oh=>oh
# The word it maps with it=>It
# The word is maps with is=>Is
# The word in maps with in=>In
# The word that maps with that=>That
# The word no maps with No=>no
# The word launcelot maps with LAUNCELOT=>Launcelot
# The word not maps with not=>Not
# The word galahad maps with GALAHAD=>Galahad
# The word knight maps with KNIGHT=>Knight=>knight
# The word what maps with What=>what
# The word father maps with FATHER=>father=>Father
# The word we maps with we=>We
# The word bedevere maps with BEDEVERE=>Bedevere
# The word this maps with this=>This
# The word well maps with Well=>well
# The word head maps with HEAD=>head
# The word have maps with have=>Have
# The word guard maps with GUARD=>guard
# The word are maps with are=>Are
# The word sir maps with Sir=>sir=>SIR
# The word on maps with on=>On
# The word ni maps with Ni=>NI=>ni
# The word he maps with He=>he
# The word be maps with be=>Be
# The word yes maps with Yes=>yes
# The word ha maps with ha=>Ha
# The word robin maps with ROBIN=>Robin
# The word my maps with my=>My
# The word with maps with with=>With
# The word witch maps with witch=>WITCH
# The word knights maps with KNIGHTS=>Knights=>knights
# The word do maps with do=>Do
# The word here maps with here=>Here
# The word grail maps with Grail=>grail
# The word for maps with for=>For
# The word one maps with one=>One
# The word but maps with but=>But
# The word black maps with BLACK=>Black
# The word burn maps with Burn=>burn
# The word all maps with all=>All=>ALL
# The word tim maps with TIM=>Tim
# The word french maps with FRENCH=>French
# The word king maps with King=>king
# The word at maps with at=>At
# The word right maps with Right=>right=>RIGHT
# The word don maps with don=>Don
# The word come maps with Come=>come
# The word uh maps with uh=>Uh
# The word herbert maps with HERBERT=>Herbert
# The word there maps with there=>There
# The word who maps with Who=>who
# The word just maps with just=>Just
# The word scene maps with SCENE=>scene
# The word tell maps with tell=>Tell
# The word if maps with if=>If
# The word look maps with Look=>look
# The word holy maps with Holy=>holy
# The word will maps with will=>Will
# The word go maps with go=>Go
# The word dead maps with dead=>DEAD
# The word dennis maps with DENNIS=>Dennis
# The word shall maps with shall=>Shall
# The word get maps with get=>Get
# The word so maps with so=>So
# The word castle maps with castle=>Castle
# The word they maps with they=>They
# The word very maps with very=>Very
# The word see maps with see=>See
# The word brave maps with brave=>Brave
# The word stop maps with Stop=>stop
# The word then maps with then=>Then
# The word by maps with by=>By
# The word say maps with say=>Say
# The word zoot maps with ZOOT=>Zoot
# The word master maps with MASTER=>master
# The word hee maps with hee=>Hee
# The word when maps with when=>When
# The word shut maps with Shut=>shut
# The word now maps with now=>Now
# The word make maps with make=>Make
# The word man maps with man=>MAN=>Man
# The word heh maps with heh=>Heh
# The word concorde maps with CONCORDE=>Concorde
# The word three maps with Three=>three
# The word maynard maps with MAYNARD=>Maynard
# The word our maps with our=>Our
# The word woman maps with WOMAN=>woman
# The word good maps with good=>Good
# The word she maps with she=>She
# The word god maps with God=>GOD
# The word officer maps with OFFICER=>officer
# The word please maps with Please=>please
# The word back maps with back=>Back
# The word did maps with did=>Did
# The word how maps with How=>how
# The word um maps with um=>Um
# The word left maps with LEFT=>left
# The word may maps with may=>May
# The word lord maps with Lord=>lord
# The word let maps with Let=>let
# The word thank maps with Thank=>thank
# The word old maps with OLD=>old=>Old
# The word where maps with Where=>where
# The word person maps with PERSON=>person
# The word yeah maps with Yeah=>yeah
# The word round maps with Round=>round
# The word guest maps with GUEST=>guest
# The word sorry maps with Sorry=>sorry
# The word eh maps with eh=>Eh
# The word quite maps with quite=>Quite
# The word haw maps with haw=>Haw
# The word cut maps with cut=>Cut
# The word peril maps with peril=>Peril
# The word second maps with second=>SECOND
# The word course maps with course=>Course
# The word would maps with would=>Would
# The word nothing maps with nothing=>Nothing
# The word bridge maps with Bridge=>bridge
# The word death maps with Death=>death
# The word quiet maps with quiet=>Quiet
# The word ooh maps with Ooh=>ooh
# The word listen maps with Listen=>listen
# The word why maps with Why=>why
# The word over maps with over=>Over
# The word open maps with open=>Open
# The word enchanter maps with enchanter=>ENCHANTER
# The word until maps with Until=>until
# The word keep maps with keep=>Keep
# The word hand maps with hand=>Hand
# The word grenade maps with Grenade=>grenade
# The word brother maps with Brother=>BROTHER
# The word court maps with court=>Court
# The word fine maps with fine=>Fine
# The word n maps with n=>N
# The word bravely maps with bravely=>Bravely
# The word never maps with never=>Never
# The word clear maps with Clear=>clear
# The word winter maps with Winter=>winter
# The word pull maps with Pull=>pull
# The word bloody maps with Bloody=>bloody
# The word princess maps with Princess=>PRINCESS
# The word idiom maps with Idiom=>idiom
# The word bors maps with Bors=>BORS

# %% [markdown]
# ### 2. Punctuation
#
# Punctuation can be tricky to handle. The easiest thing is to remove it, but that's not always the best thing to do. To practice playing around with it, count the number of **unique** words that have punctuation in them _Beowulf_. Print out a few to look at (although there are a lot, so maybe don't print them all).

# %%
beowulf = open("beowulf.txt").read()

# %%
# APPROACH BASED ON TOKENIZATION LECTURE... HAS REDUNDANCIES...
beo_tokens = beowulf.split() # leaving nothing in parentheses refers to "whitespace"
# we have already imported the String:Punctuation and collections:Counter...
punct_set = set(punctuation) #creating variable 'punct_set' as a SET using library punctuation

beo_tokens_punct = []  # creating a blank LIST... so COULD HAVE DUPLICATES (unlike a SET)

for w in beo_tokens :  #using 'w' to represent the key in each record/member of dict
    # NOTE:  rather than creating beo_tokens, could have just put in beowulf.split() here..
    w_set = set(w)   # make a set out of the key elements
    overlap = w_set.intersection(punct_set) # identify (via "intersection") punctuation in key
    
    if len(overlap) > 0 :  # if ANY punctuation in a key, returns > 0
        beo_tokens_punct.append(w)  # ADD this KEY into the LIST "beo_tokens_punct"

print(len(beo_tokens_punct))

print(beo_tokens_punct[:20])
# Out:
# 5921
# ['LO,', 'people-kings', 'spear-armed', 'Danes,', 'sped,', 'heard,', 'won!', 'foes,', 'tribe,', 'mead-bench', 'tore,', 'earls.', 'friendless,', 'foundling,', 'him:', 'welkin,', 'throve,', 'folk,', 'near,', 'whale-path,']

# %%
# EXTRA CODE NEEDED TO MAKE THIS UNIQUE
beo_tokens_punct_uniq = []
for b in beo_tokens_punct :
    if b not in beo_tokens_punct_uniq :
        beo_tokens_punct_uniq.append(b)
        
print(len(beo_tokens_punct_uniq))
print(beo_tokens_punct_uniq[:20])
# Out:
# 3478
# ['LO,', 'people-kings', 'spear-armed', 'Danes,', 'sped,', 'heard,', 'won!', 'foes,', 'tribe,', 'mead-bench', 'tore,', 'earls.', 'friendless,', 'foundling,', 'him:', 'welkin,', 'throve,', 'folk,', 'near,', 'whale-path,']

# %%
punct_set = set(punctuation)
punct_set # Made it a set, but unlike dictionary.. does NOT need pairs??  CORRECT!

# %% [markdown]
# A ***set*** is an unordered and mutable collection of ***unique elements***. Sets are written with curly brackets ({}), being the elements separated by commas.

# %%
# APPROACH PER JOHN'S SOLUTIONS... CLEANER/LESS CODE
punct_set = set(punctuation)
punct_words = set() # creates blank SET (since we want uniques)

for word in beowulf.split() :
    wset = set(word)  # make a set out of the key elements
    if punct_set.intersection(wset) : # "TRUE" means there is a punctuation in this KEY
        punct_words.add(word) # "TRUE" above means add this 
    
print(len(punct_words))

# Let's print 20 or so
print(list(punct_words)[:20]) # prints out the first 20, but in a LIST format

# %%
# While we're here, we can use the `isalnum` function to test if a string is alphanumeric. 
# This makes the code much simpler. There are also functions like isalpha and isnumeric
# https://docs.python.org/3/library/stdtypes.html#str.isalpha
punct_set_2 = set() 

for word in beowulf.split() :
    if not word.isalnum() :
        punct_set_2.add(word)

print(len(punct_set_2))
print(list(punct_set_2)[:20])

# %%
punct_set_3 = set() 

for word in beowulf.split() :
    if not word.isalpha() :  # CHANGED FUNCTION TO ISALPHA
        punct_set_3.add(word)

print(len(punct_set_3))
print(list(punct_set_3)[:20])

# %%
punct_set_4 = set() 

for word in beowulf.split() :
    if not word.isnumeric() :  # CHANGED FUNCTION TO ISNUMERIC
        punct_set_4.add(word)

print(len(punct_set_4))
print(list(punct_set_4)[:20])

# %% [markdown]
# Now let's count the number of words that have punctuation in the _middle_ of the word. Let's also throw them in a `Counter` object and look at the most common.

# %% [markdown]
# ***From John***:
# Lots of that punctuation is at the end of words (e.g., "gallows." and "vain;"). Let's count the number of words that have punctuation in the middle of the word. Let's also throw them in a Counter object and look at the most common.

# %%
punct_mid_words = [] # Use a LIST (vs a SET) so we can use a counter. 

for word in beowulf.split() :
    if not word.isalnum() and not len(word) > 1:
        print(word)
# Out:
# "

# %%
punct_mid_words = [] # Use a LIST (vs a SET) so we can use a counter. 

for word in beowulf.split() :
    if not word.isalnum() and len(word) > 1: # 'len(word) is counting characters'
        # 2 conditions.. can't be alpha-numeric, must have more than 1 character
        # now we're in the case of punctuation somewhere
        # need to test if it's start or end. 
        if (not word[1] in punctuation and
            not word[-1] in punctuation) : # punctuation NOT in first or last position..
            punct_mid_words.append(word) # then add this word to our "mid-word-punctuation"

# %%
Counter(punct_mid_words).most_common(20)

# %% [markdown]
# ### Stopwords
#
# There are many common words that don't help analysis that much (and can take up a lot of space). These are called stopwords. Let's play around with the English stopwords.
# 1. Load in the English stopwords and assign them to a variable called `sw`. Print them out. Any surprises?
# 1. Look at the top words in _Moby Dick_ and _Sense and Sensibility_.
# 1. Look at the top words in both of those that _aren't_ stopwords.
#
# **When might you need to keep what is considered a 'Stopword'**?
# - when you DO care about the use of one
# - when a stopword has a different meaning (ex: woman named "May")
# - titles of material (ex: song "Me, Myself and I")

# %%
sw = stopwords.words("english")
sw

# %%
Counter(text1).most_common(10)

# %%
Counter(text2).most_common(10)

# %% [markdown]
# To look at the same stats but without stopwords and non-alpha strings, I'm going to use a list comprehension. If you haven't seen these before, here's a nice tutorial: https://www.youtube.com/watch?v=AhSvKGTh28Q

# %% [markdown]
# ### see "List Comprehension" notebook...

# %%
Counter([w for w in text1 if w.lower() not in sw and w.isalpha()]).most_common(10)

# %%
Counter([w for w in text2 if w.lower() not in sw and w.isalpha()]).most_common(10)

# %% [markdown]
# ### Lemmas vs Stemming (from John's lecture on normalization, 9/8/21 class review)
#
# -	19:52-m – review text normalization /lemma /stemming
# -	20:29m  lemma defined:  generally used in different parts of speech (noun vs verb, etc)
# -	20:55m	 stemming defined
# -	21:36m  example:  learn, learns, learning… **diff lemmas, same stem**
# -	21:30m whiteboard
# -	22:44m  whiteboard “wordform vs lemma”
# -	23:30m  type vs tokens (each instance of the type):  => complexity vs size of the corpus
# o	Want a set of tokens to work with
# -	24:30m  steps to normalize a corpus (keep what needs being kept, delete what doesn’t)
# o	Ex: sarcasm/satire?  “I’m REALLY excited…” vs. “i’m really excited…”
# -	26:15m whiteboard:  stop words, punctuation, case-folding
# o	case-folding (make all lower or all upper);  ? re: formatting (bold, italics, etc)
# -	30:40m – punctuation:  tend to strip out.. make simpler, don’t care about it
# -	35:55m:  dealing with “it’s” => “it is” before other cleansing…
# -	36:25m – stop words;  generally don’t contain much value, so remove
# o	MacBeth:  an exception
# o	Can add words… ex: Twitter “rt” (re-tweet) or NOT delete (“#”, “@”)
# -	41:05m  stemming (vs tokenization)
# o	Always need tokenization
# o	Almost always need normalization
# o	Stemming is more of “maybe” to do it..

# %% [markdown]
# ## Stemming
#
# Stemming is the process by which we move from a token to some "root" of that word. Let's explore one of the stemmers available through NLTK.
#
# First, let's find all the words in the NLTK words corpus that end in "ing", then let's find those that have no vowels before an instance of "ing". You can access the words corpus with the confusing call of `nltk.corpus.words.words()`. To make it easier to deal with "y", let's just consider it a vowel.

# %%
words = nltk.corpus.words.words()
vowels = set('aeiouy')
vowels

# %%
# 2 conditions.. word length > 3 characters, and last 3 MUST be 'ing'
# (Not YET concerned about ANY preceeding characters being a vowel...)
ing_words = [w for w in words if len(w) > 3 and w[-3:]=="ing"]

# %%
len(ing_words)

# %%
# Now let's find the subset that don't have a vowel before the 'ing'
ing_no_vowel = []  # creating a blank LIST

for word in ing_words :  # iterate over each "ing_word"...
    remainder = word[:-3] # identifies all characters preceeding the 'ing'
    # we have a set "vowels", so convert "remainder" to a set, for intersection testing
    # determine if any of the characters in our remainder intersect with vowels;
    #   count the number of intersections
    if len(set(remainder).intersection(vowels))==0 : # looking for 0 intersections!
        ing_no_vowel.append(word) # TRUE... make this an 'ing_no_vowel' word (ex: sing)
        
ing_no_vowel

# %% [markdown]
# Now let's play around with the Porter Stemmer in NLTK. First we'll look at a few hundred characters of inaugural addresses both stemmed and not stemmed.

# %%
porter = nltk.PorterStemmer() # give it a short name.
start = 30000
distance = 200 # (will actually return 201)
# join the text starting at 30,000 and ending with 30,200... 
# but then separate with a space
print(" ".join(text4[start:(start + distance)]))

# %%
print("\n\n") # this is just to create a separator between these two outputs...

# %%
# to get the stem of each, take the ORIGINAL..
#    text4[start:(start + distance)]
# and make a list comprehension out of it
#    [porter.stem(w) for w in ORIGINAL]
print(" ".join([porter.stem(w) for w in text4[start:(start + distance)]]))

# %% [markdown]
# Now for you: how many words are in the inaugural addresses? How many lowercase stems are in them?

# %%
# words in inaugural addresses
print(len(set(text4)))

# %%
# Identify the lower-cased stems by adding in the qualifier for w
#    ie, "porter.stem(w.lower())..."  INSTEAD OF "porter.stem(w)...""
inaug_stemmed = {porter.stem(w.lower()) for w in text4}
# what is the number of lower-cased stems?
print(len(inaug_stemmed))
# what is the multiple of total words to these lower-case stemmed words?
print(len(set(text4))/len(inaug_stemmed))

# %% [markdown]
# ---
#
# Okay, let's have some "fun" and play around with some sets of characters that aren't words. Text 5 is the chat corpus. Find the emojis in there (doesn't have to be perfect) and count up the happy and sad ones.

# %%
chat = text5 # give it a nice name. 

# Let's find emojis in chat. Assume an emoji if includes ":", ";", "="
potential_emojis = {w for w in chat if ":" in w or ";" in w or "=" in w}

# %%
potential_emojis

# %% [markdown]
# Some non-emoji's present... but we've likely captured most/all true emoji's

# %%
# Count happy vs sad
# we're looking at the options and make our own call on which are happy vs sad
happy = [w for w in chat if w in {":-)",":)",":D",";-)","=)"}]
sad = [w for w in chat if w in {":-(",":(",";-(","=("}]

print(len(happy))
print(len(sad))
